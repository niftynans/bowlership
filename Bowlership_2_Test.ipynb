# %%
import pandas as pd
import numpy as np
import yaml
import math
import os
import matplotlib.pyplot as plt
import scipy.stats

# %%
og_data = pd.read_csv('/home/pnans/Documents/Projects/Bowlership/Main Stuff/testout.csv')
og_data
# Out:
#        runs  wicket  over      bowler
# 0        10       0     1       B Lee
# 1         7       0     2   PM Siddle
# 2         4       0     3       B Lee
# 3         4       0     4   PM Siddle
# 4         4       0     5       B Lee
# ...     ...     ...   ...         ...
# 65636     2       0   125    RL Chase
# 65637     0       0   126  ML Cummins
# 65638     1       0   127    RL Chase
# 65639     0       1   128  ML Cummins
# 65640     2       1   129  ST Gabriel
#
# [65641 rows x 4 columns]

# %%
bnames = og_data['bowler'].unique()
bdfdict = {}
arr = []
arr2 = []
normbowl = 0
for name in bnames:
    bdfdict[name] = og_data.loc[og_data['bowler'] == name]
    if(len(bdfdict[name])>7):
        if(scipy.stats.normaltest(bdfdict[name]['runs'])[1]>0.001):
            normbowl += 1
            arr2.append(name)
            arr.append(scipy.stats.normaltest(bdfdict[name]['runs'])[0])
print(len(bnames))
print(normbowl)
#plt.plot(arr2, arr, 'o', color='red')
# Out:
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# 495
# 213
# /home/pnans/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
#D’Agostino’s K^2 Test

notnormcount = 0
maybenormcount = 0
for name in bdfdict:
    
    if(len(bdfdict[name]['runs'])>=8):
        
        print(name)
        print(scipy.stats.normaltest(bdfdict[name]['runs']))
        
        if(scipy.stats.normaltest(bdfdict[name]['runs'])[1] < 0.05):
            print("Data is not normal")
            notnormcount += 1
        else:
            print("Data may be normal")
            maybenormcount += 1
print(notnormcount, maybenormcount)
# Out:
# B Lee
# NormaltestResult(statistic=48.54792825304602, pvalue=2.8704588539334426e-11)
# Data is not normal
# PM Siddle
# NormaltestResult(statistic=103.3487864267124, pvalue=3.614899034084493e-23)
# Data is not normal
# MG Johnson
# NormaltestResult(statistic=61.92007416500591, pvalue=3.5828344014755e-14)
# Data is not normal
# SR Watson
# NormaltestResult(statistic=32.02113863426304, pvalue=1.1135201836080965e-07)
# Data is not normal
# MJ Clarke
# NormaltestResult(statistic=18.036776270451625, pvalue=0.00012116126450256166)
# Data is not normal
# CL White
# NormaltestResult(statistic=4.928494578963506, pvalue=0.08507285350940276)
# Data may be normal
# JM Anderson
# NormaltestResult(statistic=240.17640611565213, pvalue=7.0203064494894745e-53)
# Data is not normal
# SCJ Broad
# NormaltestResult(statistic=196.7103319943476, pvalue=1.927055136378585e-43)
# Data is not normal
# MS Panesar
# NormaltestResult(statistic=112.42189424285739, pvalue=3.8716477956989687e-25)
# Data is not normal
# GP Swann
# NormaltestResult(statistic=205.5612915292633, pvalue=2.3063897429046907e-45)
# Data is not normal
# SR Patel
# NormaltestResult(statistic=45.527959869347924, pvalue=1.299358908167133e-10)
# Data is not normal
# KM Jarvis
# NormaltestResult(statistic=25.638171428899653, pvalue=2.708580897057279e-06)
# Data is not normal
# TL Chatara
# NormaltestResult(statistic=6.686064576696618, pvalue=0.03532966540043826)
# Data is not normal
# DT Tiripano
# NormaltestResult(statistic=6.299210589262069, pvalue=0.04286904417004172)
# Data is not normal
# Sikandar Raza
# NormaltestResult(statistic=18.432439205734894, pvalue=9.94138017966777e-05)
# Data is not normal
# SC Williams
# NormaltestResult(statistic=31.52125336437779, pvalue=1.4297062002169435e-07)
# Data is not normal
# B Mavuta
# NormaltestResult(statistic=3.452607161128152, pvalue=0.17794094016652393)
# Data may be normal
# H Masakadza
# NormaltestResult(statistic=18.990203303717227, pvalue=7.521937966799215e-05)
# Data is not normal
# BW Hilfenhaus
# NormaltestResult(statistic=27.456625621352433, pvalue=1.0911124229088543e-06)
# Data is not normal
# XJ Doherty
# NormaltestResult(statistic=5.218966197337502, pvalue=0.07357256369205038)
# Data may be normal
# MJ North
# NormaltestResult(statistic=2.6675224209176447, pvalue=0.26348437505607)
# Data may be normal
# CT Tremlett
# NormaltestResult(statistic=33.24365060323326, pvalue=6.042727255086217e-08)
# Data is not normal
# TT Bresnan
# NormaltestResult(statistic=46.458218824078216, pvalue=8.160672753793311e-11)
# Data is not normal
# MA Starc
# NormaltestResult(statistic=51.33983822471757, pvalue=7.1071548612628186e-12)
# Data is not normal
# NM Lyon
# NormaltestResult(statistic=233.39972150987734, pvalue=2.0791912328897896e-51)
# Data is not normal
# MR Marsh
# NormaltestResult(statistic=81.89486063739008, pvalue=1.64724032142326e-18)
# Data is not normal
# GJ Maxwell
# NormaltestResult(statistic=3.002358858002405, pvalue=0.22286714909842628)
# Data may be normal
# SPD Smith
# NormaltestResult(statistic=30.633028067147272, pvalue=2.22906366779381e-07)
# Data is not normal
# MA Wood
# NormaltestResult(statistic=22.709400986954943, pvalue=1.1714297033546144e-05)
# Data is not normal
# BA Stokes
# NormaltestResult(statistic=38.626598185472794, pvalue=4.095819192103397e-09)
# Data is not normal
# ST Finn
# NormaltestResult(statistic=22.376139989724088, pvalue=1.3838306266359531e-05)
# Data is not normal
# MM Ali
# NormaltestResult(statistic=53.01169916425957, pvalue=3.0807452555336487e-12)
# Data is not normal
# JE Root
# NormaltestResult(statistic=18.564025407021127, pvalue=9.308358514014843e-05)
# Data is not normal
# DW Steyn
# NormaltestResult(statistic=139.63299452196526, pvalue=4.776177888978871e-31)
# Data is not normal
# M Morkel
# NormaltestResult(statistic=183.3926866181323, pvalue=1.5023948636394436e-40)
# Data is not normal
# M de Lange
# NormaltestResult(statistic=10.21384516157896, pvalue=0.006054687092876333)
# Data is not normal
# Imran Tahir
# NormaltestResult(statistic=40.368175109167666, pvalue=1.7145973682625823e-09)
# Data is not normal
# JH Kallis
# NormaltestResult(statistic=47.534013011946904, pvalue=4.765628925510364e-11)
# Data is not normal
# Taijul Islam
# NormaltestResult(statistic=145.4634164458129, pvalue=2.588334847432336e-32)
# Data is not normal
# Shakib Al Hasan
# NormaltestResult(statistic=157.84810738458765, pvalue=5.293208387510901e-35)
# Data is not normal
# Mehedi Hasan Miraz
# NormaltestResult(statistic=55.12294722119636, pvalue=1.072022986801292e-12)
# Data is not normal
# Nayeem Hasan
# NormaltestResult(statistic=16.521303091006942, pvalue=0.00025849051800934245)
# Data is not normal
# Mahmudullah
# NormaltestResult(statistic=25.517990187486642, pvalue=2.876330829091888e-06)
# Data is not normal
# Soumya Sarkar
# NormaltestResult(statistic=2.627180507589707, pvalue=0.268853070803847)
# Data may be normal
# Mominul Haque
# NormaltestResult(statistic=9.361932887003048, pvalue=0.009270050576357379)
# Data is not normal
# B Kumar
# NormaltestResult(statistic=56.462745078468615, pvalue=5.486188047793259e-13)
# Data is not normal
# Mohammed Shami
# NormaltestResult(statistic=49.229108233710264, pvalue=2.0419023668340632e-11)
# Data is not normal
# R Ashwin
# NormaltestResult(statistic=185.4214173554375, pvalue=5.448171975316876e-41)
# Data is not normal
# PP Ojha
# NormaltestResult(statistic=108.2103485447617, pvalue=3.179957905614248e-24)
# Data is not normal
# SR Tendulkar
# NormaltestResult(statistic=3.453520349721835, pvalue=0.17785971189366345)
# Data may be normal
# Z Khan
# NormaltestResult(statistic=109.43498174721817, pvalue=1.7238348245884095e-24)
# Data is not normal
# I Sharma
# NormaltestResult(statistic=238.6240640882741, pvalue=1.5256076528090371e-52)
# Data is not normal
# Harbhajan Singh
# NormaltestResult(statistic=267.3031297283162, pvalue=9.03364212751091e-59)
# Data is not normal
# V Sehwag
# NormaltestResult(statistic=27.031081155409634, pvalue=1.349818285773059e-06)
# Data is not normal
# RAS Lakmal
# NormaltestResult(statistic=244.58943984463693, pvalue=7.728193221347486e-54)
# Data is not normal
# RMS Eranga
# NormaltestResult(statistic=40.44502370602012, pvalue=1.6499648488137997e-09)
# Data is not normal
# AD Mathews
# NormaltestResult(statistic=49.23096345424595, pvalue=2.0400091554495644e-11)
# Data is not normal
# KTGD Prasad
# NormaltestResult(statistic=8.618338138537215, pvalue=0.01344471658228911)
# Data is not normal
# PHT Kaushal
# NormaltestResult(statistic=12.290536045222387, pvalue=0.0021436012812995242)
# Data is not normal
# JL Pattinson
# NormaltestResult(statistic=22.41057528024562, pvalue=1.3602082660802368e-05)
# Data is not normal
# MEK Hussey
# NormaltestResult(statistic=4.365596607712332, pvalue=0.11272564826291585)
# Data may be normal
# Shafiul Islam
# NormaltestResult(statistic=13.746291974838206, pvalue=0.0010352151624768843)
# Data is not normal
# Robiul Islam
# NormaltestResult(statistic=17.104554530604656, pvalue=0.00019310484749406967)
# Data is not normal
# Rubel Hossain
# NormaltestResult(statistic=71.95763515598642, pvalue=2.3691800146760095e-16)
# Data is not normal
# Abdur Razzak
# NormaltestResult(statistic=66.27248471768635, pvalue=4.065489020732651e-15)
# Data is not normal
# FH Edwards
# NormaltestResult(statistic=34.015996384012325, pvalue=4.1069577678202457e-08)
# Data is not normal
# TL Best
# NormaltestResult(statistic=16.1851429396642, pvalue=0.0003058023836093494)
# Data is not normal
# DJG Sammy
# NormaltestResult(statistic=82.33816156932355, pvalue=1.3197613030597663e-18)
# Data is not normal
# SP Narine
# NormaltestResult(statistic=13.538516798561544, pvalue=0.0011485460977577664)
# Data is not normal
# V Permaul
# NormaltestResult(statistic=7.5639848971046755, pvalue=0.02277726365787557)
# Data is not normal
# MN Samuels
# NormaltestResult(statistic=33.209558484273984, pvalue=6.14661486496057e-08)
# Data is not normal
# JC Archer
# NormaltestResult(statistic=25.33539652154808, pvalue=3.1512912743036436e-06)
# Data is not normal
# CR Woakes
# NormaltestResult(statistic=66.65670022349633, pvalue=3.354914491328618e-15)
# Data is not normal
# SM Curran
# NormaltestResult(statistic=13.001248266311551, pvalue=0.0015025011394951332)
# Data is not normal
# JL Denly
# NormaltestResult(statistic=1.64989131314515, pvalue=0.43825880830356845)
# Data may be normal
# JJ Bumrah
# NormaltestResult(statistic=55.90255575447493, pvalue=7.259626140305988e-13)
# Data is not normal
# GH Vihari
# NormaltestResult(statistic=0.9542987921059876, pvalue=0.6205498146750124)
# Data may be normal
# RA Jadeja
# NormaltestResult(statistic=212.3192320250128, pvalue=7.860760505722405e-47)
# Data is not normal
# Mohammad Sami
# NormaltestResult(statistic=18.605222855539274, pvalue=9.118579516637886e-05)
# Data is not normal
# Umar Gul
# NormaltestResult(statistic=141.8812985313587, pvalue=1.551913393638603e-31)
# Data is not normal
# Shahid Nazir
# NormaltestResult(statistic=24.819190725369282, pvalue=4.079258351418689e-06)
# Data is not normal
# Danish Kaneria
# NormaltestResult(statistic=74.19590633921996, pvalue=7.736840586339387e-17)
# Data is not normal
# Salman Butt
# NormaltestResult(statistic=2.1752592341279917, pvalue=0.33701440084535084)
# Data may be normal
# TA Boult
# NormaltestResult(statistic=171.93566110077236, pvalue=4.620038245876138e-38)
# Data is not normal
# TG Southee
# NormaltestResult(statistic=103.67116574970794, pvalue=3.0767512889701284e-23)
# Data is not normal
# C de Grandhomme
# NormaltestResult(statistic=70.05668585066554, pvalue=6.128920066522248e-16)
# Data is not normal
# N Wagner
# NormaltestResult(statistic=109.79187787286463, pvalue=1.4421041977268823e-24)
# Data is not normal
# AY Patel
# NormaltestResult(statistic=16.43905927687853, pvalue=0.0002693417231090001)
# Data is not normal
# Mohammad Asif
# NormaltestResult(statistic=31.454369728043595, pvalue=1.4783266214832692e-07)
# Data is not normal
# KAJ Roach
# NormaltestResult(statistic=176.66535702607558, pvalue=4.341153576064337e-39)
# Data is not normal
# JO Holder
# NormaltestResult(statistic=119.31570843684189, pvalue=1.2328865386941404e-26)
# Data is not normal
# RRS Cornwall
# NormaltestResult(statistic=35.00542223246992, pvalue=2.504200764944809e-08)
# Data is not normal
# JA Warrican
# NormaltestResult(statistic=59.00541754366766, pvalue=1.5386377346985962e-13)
# Data is not normal
# RL Chase
# NormaltestResult(statistic=104.82295135544568, pvalue=1.7297579079912663e-23)
# Data is not normal
# T Thushara
# NormaltestResult(statistic=5.555890052551495, pvalue=0.06216612596141888)
# Data may be normal
# BAW Mendis
# NormaltestResult(statistic=34.76850000133006, pvalue=2.8191368126467722e-08)
# Data is not normal
# S Randiv
# NormaltestResult(statistic=65.6072368593219, pvalue=5.6698233681333986e-15)
# Data is not normal
# TM Dilshan
# NormaltestResult(statistic=19.390654628462766, pvalue=6.157052364336444e-05)
# Data is not normal
# N Pradeep
# NormaltestResult(statistic=50.649855464963075, pvalue=1.003514451706965e-11)
# Data is not normal
# PVD Chameera
# NormaltestResult(statistic=8.437057673385514, pvalue=0.01472028452546271)
# Data is not normal
# HMRKB Herath
# NormaltestResult(statistic=180.91138587170465, pvalue=5.195073558387224e-40)
# Data is not normal
# TAM Siriwardana
# NormaltestResult(statistic=2.4401424970085777, pvalue=0.2952091329655278)
# Data may be normal
# JS Patel
# NormaltestResult(statistic=58.707784339843364, pvalue=1.7855277664345217e-13)
# Data is not normal
# MJ Santner
# NormaltestResult(statistic=62.09863254078093, pvalue=3.276825215411108e-14)
# Data is not normal
# JDS Neesham
# NormaltestResult(statistic=14.06151282467559, pvalue=0.0008842626603761635)
# Data is not normal
# KJ Abbott
# NormaltestResult(statistic=23.232122167975778, pvalue=9.020046362033861e-06)
# Data is not normal
# DL Piedt
# NormaltestResult(statistic=17.81456819343133, pvalue=0.0001353990658475392)
# Data is not normal
# D Elgar
# NormaltestResult(statistic=4.5178009888259, pvalue=0.1044652817941925)
# Data may be normal
# JP Duminy
# NormaltestResult(statistic=38.246672144713536, pvalue=4.9526845583466835e-09)
# Data is not normal
# UT Yadav
# NormaltestResult(statistic=34.5662136443208, pvalue=3.119191775010193e-08)
# Data is not normal
# M Vijay
# NormaltestResult(statistic=6.203775362610541, pvalue=0.04496424406873085)
# Data is not normal
# ST Gabriel
# NormaltestResult(statistic=74.25501591492484, pvalue=7.511525869019719e-17)
# Data is not normal
# AS Joseph
# NormaltestResult(statistic=35.64891850144425, pvalue=1.8152469030990497e-08)
# Data is not normal
# CK Holder
# NormaltestResult(statistic=4.344739578132452, pvalue=0.11390736039461984)
# Data may be normal
# ZS Ansari
# NormaltestResult(statistic=4.2337784577687545, pvalue=0.12040560080391986)
# Data may be normal
# AU Rashid
# NormaltestResult(statistic=36.468486284424905, pvalue=1.2049494329917734e-08)
# Data is not normal
# DBL Powell
# NormaltestResult(statistic=36.80561872821759, pvalue=1.0180320285299485e-08)
# Data is not normal
# LS Baker
# NormaltestResult(statistic=17.2781551702272, pvalue=0.00017705014062958924)
# Data is not normal
# BP Nash
# NormaltestResult(statistic=6.389265303459089, pvalue=0.040981577122773706)
# Data is not normal
# CH Gayle
# NormaltestResult(statistic=81.70016635701487, pvalue=1.8156590148315332e-18)
# Data is not normal
# RO Hinds
# NormaltestResult(statistic=18.191916697978, pvalue=0.00011211803597513652)
# Data is not normal
# LMP Simmons
# NormaltestResult(statistic=1.7409831777578582, pvalue=0.418745647938762)
# Data may be normal
# Junaid Khan
# NormaltestResult(statistic=36.35210583260233, pvalue=1.2771459063520058e-08)
# Data is not normal
# Rahat Ali
# NormaltestResult(statistic=20.43129086533414, pvalue=3.659329860055223e-05)
# Data is not normal
# Saeed Ajmal
# NormaltestResult(statistic=121.92731671427043, pvalue=3.3405623253609416e-27)
# Data is not normal
# Younis Khan
# NormaltestResult(statistic=2.151846570845364, pvalue=0.340982785484625)
# Data may be normal
# Mohammad Hafeez
# NormaltestResult(statistic=37.12282674002934, pvalue=8.68721554151189e-09)
# Data is not normal
# SR Clark
# NormaltestResult(statistic=25.520632081211993, pvalue=2.872533857258315e-06)
# Data is not normal
# MS Kasprowicz
# NormaltestResult(statistic=8.06112613945716, pvalue=0.017764324583641584)
# Data is not normal
# SK Warne
# NormaltestResult(statistic=24.739728775641012, pvalue=4.244593986782861e-06)
# Data is not normal
# A Symonds
# NormaltestResult(statistic=16.364203647576673, pvalue=0.00027961362351092465)
# Data is not normal
# Shahadat Hossain
# NormaltestResult(statistic=44.00129751875383, pvalue=2.787658986187982e-10)
# Data is not normal
# Enamul Haque jnr
# NormaltestResult(statistic=13.612148883532397, pvalue=0.0011070300925318166)
# Data is not normal
# Mohammad Ashraful
# NormaltestResult(statistic=3.3756750958762733, pvalue=0.18491897035424812)
# Data may be normal
# MJ Henry
# NormaltestResult(statistic=46.869376652786116, pvalue=6.644222609556607e-11)
# Data is not normal
# DAJ Bracewell
# NormaltestResult(statistic=39.9018221940551, pvalue=2.164857934036787e-09)
# Data is not normal
# MD Craig
# NormaltestResult(statistic=22.013793092873446, pvalue=1.6586913009767073e-05)
# Data is not normal
# KS Williamson
# NormaltestResult(statistic=38.85472600947858, pvalue=3.654293699317034e-09)
# Data is not normal
# BB McCullum
# NormaltestResult(statistic=4.131662298793678, pvalue=0.12671292941377657)
# Data may be normal
# C Overton
# NormaltestResult(statistic=11.613001037534339, pvalue=0.0030079378978562204)
# Data is not normal
# CBRLS Kumara
# NormaltestResult(statistic=36.74186757707081, pvalue=1.0510051115742039e-08)
# Data is not normal
# CAK Rajitha
# NormaltestResult(statistic=10.40225004675294, pvalue=0.005510361646616795)
# Data is not normal
# MDK Perera
# NormaltestResult(statistic=80.70373358032646, pvalue=2.988181127469164e-18)
# Data is not normal
# GD McGrath
# NormaltestResult(statistic=50.955399762285396, pvalue=8.613418128051464e-12)
# Data is not normal
# JN Gillespie
# NormaltestResult(statistic=20.14820294041382, pvalue=4.2157351740560706e-05)
# Data is not normal
# M Ntini
# NormaltestResult(statistic=78.6024524087636, pvalue=8.544650969030462e-18)
# Data is not normal
# PL Harris
# NormaltestResult(statistic=190.00512494493188, pvalue=5.5069527666835477e-42)
# Data is not normal
# CS Martin
# NormaltestResult(statistic=76.2870622877693, pvalue=2.719411337949199e-17)
# Data is not normal
# IE O'Brien
# NormaltestResult(statistic=44.35209446167228, pvalue=2.3391876222284525e-10)
# Data is not normal
# GD Elliott
# NormaltestResult(statistic=9.524520871204338, pvalue=0.008546269255869007)
# Data is not normal
# DL Vettori
# NormaltestResult(statistic=138.56645182229093, pvalue=8.140991444449387e-31)
# Data is not normal
# JD Ryder
# NormaltestResult(statistic=6.638024664255768, pvalue=0.03618855638358623)
# Data is not normal
# KC Brathwaite
# NormaltestResult(statistic=114.94395172200794, pvalue=1.097079296827677e-25)
# Data is not normal
# KH Brunt
# NormaltestResult(statistic=19.07249490593068, pvalue=7.218722599718623e-05)
# Data is not normal
# A Shrubsole
# NormaltestResult(statistic=12.575947975638208, pvalue=0.0018585215223126323)
# Data is not normal
# S Ecclestone
# NormaltestResult(statistic=10.208054524346398, pvalue=0.006072242743469188)
# Data is not normal
# NR Sciver
# NormaltestResult(statistic=1.2777220885274114, pvalue=0.5278933289111813)
# Data may be normal
# KL Gordon
# NormaltestResult(statistic=2.793109882382065, pvalue=0.24744797002582625)
# Data may be normal
# LA Marsh
# NormaltestResult(statistic=6.358193558694502, pvalue=0.0416232331117906)
# Data is not normal
# JE Taylor
# NormaltestResult(statistic=53.50113076216463, pvalue=2.4119986878272366e-12)
# Data is not normal
# J Blackwood
# NormaltestResult(statistic=5.206404440337937, pvalue=0.07403611826658522)
# Data may be normal
# Pankaj Singh
# NormaltestResult(statistic=31.37488177406998, pvalue=1.5382643939107918e-07)
# Data is not normal
# RG Sharma
# NormaltestResult(statistic=2.046738450013736, pvalue=0.3593820590653291)
# Data may be normal
# NM Hauritz
# NormaltestResult(statistic=34.12469358634231, pvalue=3.889707456357609e-08)
# Data is not normal
# SM Katich
# NormaltestResult(statistic=9.098072890603637, pvalue=0.010577391370354548)
# Data is not normal
# Shoaib Akhtar
# NormaltestResult(statistic=6.839207596668098, pvalue=0.032725398228108764)
# Data is not normal
# Sohail Tanvir
# NormaltestResult(statistic=18.14204050927058, pvalue=0.00011494920134394474)
# Data is not normal
# Yasir Hameed
# NormaltestResult(statistic=0.8469975302933819, pvalue=0.6547519841885887)
# Data may be normal
# Mashrafe Mortaza
# NormaltestResult(statistic=25.342684886920427, pvalue=3.1398282924884324e-06)
# Data is not normal
# Mohammad Rafique
# NormaltestResult(statistic=44.00252701117963, pvalue=2.7859458100215997e-10)
# Data is not normal
# Aftab Ahmed
# NormaltestResult(statistic=22.680313683658117, pvalue=1.1885910607997376e-05)
# Data is not normal
# RJ Harris
# NormaltestResult(statistic=37.422961521599035, pvalue=7.476651835089757e-09)
# Data is not normal
# TA Copeland
# NormaltestResult(statistic=4.331147184339036, pvalue=0.1146841338065543)
# Data may be normal
# VR Aaron
# NormaltestResult(statistic=22.230245935365616, pvalue=1.4885500082087606e-05)
# Data is not normal
# KV Sharma
# NormaltestResult(statistic=4.570166727944825, pvalue=0.10176557816981024)
# Data may be normal
# VD Philander
# NormaltestResult(statistic=129.46770473046905, pvalue=7.699191563487915e-29)
# Data is not normal
# A Dananjaya
# NormaltestResult(statistic=9.023561583372508, pvalue=0.010978891638280015)
# Data is not normal
# DM de Silva
# NormaltestResult(statistic=16.84748705870043, pvalue=0.00021959106662942948)
# Data is not normal
# D Bishoo
# NormaltestResult(statistic=66.73427277472908, pvalue=3.2272810661145694e-15)
# Data is not normal
# IS Sodhi
# NormaltestResult(statistic=24.96899510558187, pvalue=3.7848755447508233e-06)
# Data is not normal
# KA Maharaj
# NormaltestResult(statistic=121.02243922535581, pvalue=5.2518368844505906e-27)
# Data is not normal
# K Rabada
# NormaltestResult(statistic=74.67711312703575, pvalue=6.082343205543828e-17)
# Data is not normal
# AK Markram
# NormaltestResult(statistic=20.375718333633333, pvalue=3.7624347892107284e-05)
# Data is not normal
# TB de Bruyn
# NormaltestResult(statistic=2.159984049864825, pvalue=0.3395982339530081)
# Data may be normal
# DA Warner
# NormaltestResult(statistic=1.3960732517298304, pvalue=0.4975612442873928)
# Data may be normal
# SJ Benn
# NormaltestResult(statistic=156.29330198480253, pvalue=1.1517035215625828e-34)
# Data is not normal
# S Shillingford
# NormaltestResult(statistic=121.70738625001411, pvalue=3.728866819784053e-27)
# Data is not normal
# ML Cummins
# NormaltestResult(statistic=9.384041978847701, pvalue=0.009168138709092855)
# Data is not normal
# CD Collymore
# NormaltestResult(statistic=30.142371159356244, pvalue=2.848834807702173e-07)
# Data is not normal
# DJ Bravo
# NormaltestResult(statistic=94.97581830175757, pvalue=2.3782806294215194e-21)
# Data is not normal
# D Mohammed
# NormaltestResult(statistic=4.938420983407092, pvalue=0.0846516658182987)
# Data may be normal
# N Ncube
# NormaltestResult(statistic=1.907687369745866, pvalue=0.38525736601535265)
# Data may be normal
# CB Mpofu
# NormaltestResult(statistic=23.428307141905737, pvalue=8.177258821122764e-06)
# Data is not normal
# RW Price
# NormaltestResult(statistic=9.058370142855864, pvalue=0.010789465134443317)
# Data is not normal
# MN Waller
# NormaltestResult(statistic=9.884125625383106, pvalue=0.007139854987637719)
# Data is not normal
# SM Pollock
# NormaltestResult(statistic=39.77952779652519, pvalue=2.301363880447005e-09)
# Data is not normal
# A Nel
# NormaltestResult(statistic=45.45735075048195, pvalue=1.3460515843884072e-10)
# Data is not normal
# N Boje
# NormaltestResult(statistic=13.013523492847293, pvalue=0.0014933076105891022)
# Data is not normal
# HH Pandya
# NormaltestResult(statistic=3.3816535628097273, pvalue=0.18436702973011468)
# Data may be normal
# DE Bollinger
# NormaltestResult(statistic=7.913478105281729, pvalue=0.019125379570539957)
# Data is not normal
# PLS Gamage
# NormaltestResult(statistic=9.183488336888784, pvalue=0.010135165512324839)
# Data is not normal
# IDR Bradshaw
# NormaltestResult(statistic=33.587934340425946, pvalue=5.087128742910114e-08)
# Data is not normal
# RJ Sidebottom
# NormaltestResult(statistic=17.653698851034314, pvalue=0.00014673982672382702)
# Data is not normal
# PD Collingwood
# NormaltestResult(statistic=8.362632943163092, pvalue=0.01527838076736035)
# Data is not normal
# KP Pietersen
# NormaltestResult(statistic=7.409815594367444, pvalue=0.0246024856815315)
# Data is not normal
# HK Bennett
# NormaltestResult(statistic=2.6799608558915216, pvalue=0.2618507934881061)
# Data may be normal
# IK Pathan
# NormaltestResult(statistic=52.55530724973898, pvalue=3.870437272849168e-12)
# Data is not normal
# SC Ganguly
# NormaltestResult(statistic=8.904701187667786, pvalue=0.011651147641363982)
# Data is not normal
# A Kumble
# NormaltestResult(statistic=67.38389862692048, pvalue=2.332235107678599e-15)
# Data is not normal
# Mohammad Amir
# NormaltestResult(statistic=41.26447816351322, pvalue=1.0952983097806067e-09)
# Data is not normal
# Abdur Rauf
# NormaltestResult(statistic=2.5165804359082427, pvalue=0.2841394279085777)
# Data may be normal
# Shoaib Malik
# NormaltestResult(statistic=6.84103633006347, pvalue=0.0326954888899357)
# Data is not normal
# L Ngidi
# NormaltestResult(statistic=11.216482183713177, pvalue=0.0036675145089907863)
# Data is not normal
# JR Hazlewood
# NormaltestResult(statistic=161.63026502123313, pvalue=7.987923488231163e-36)
# Data is not normal
# PJ Cummins
# NormaltestResult(statistic=68.15300847344075, pvalue=1.5876773438239284e-15)
# Data is not normal
# Wahab Riaz
# NormaltestResult(statistic=48.81077170611985, pvalue=2.5169558364042102e-11)
# Data is not normal
# Yasir Shah
# NormaltestResult(statistic=102.79842235088654, pvalue=4.7599918850468296e-23)
# Data is not normal
# Azhar Ali
# NormaltestResult(statistic=26.306308163000566, pvalue=1.939357003155711e-06)
# Data is not normal
# Shan Masood
# NormaltestResult(statistic=6.323188671143671, pvalue=0.04235815410482166)
# Data is not normal
# AS Jaggernauth
# NormaltestResult(statistic=3.427991850639957, pvalue=0.18014450847542124)
# Data may be normal
# Abdul Razzaq
# NormaltestResult(statistic=4.042236011996071, pvalue=0.13250723834911665)
# Data may be normal
# JM Holland
# NormaltestResult(statistic=7.643489469132939, pvalue=0.021889576057868097)
# Data is not normal
# Hasan Ali
# NormaltestResult(statistic=7.456238398253815, pvalue=0.02403800404618785)
# Data is not normal
# Shaheen Shah Afridi
# NormaltestResult(statistic=49.247608581751805, pvalue=2.0231015042914723e-11)
# Data is not normal
# Bilal Asif
# NormaltestResult(statistic=9.389871452755262, pvalue=0.009141454903428749)
# Data is not normal
# Haris Sohail
# NormaltestResult(statistic=7.071035007111135, pvalue=0.029143671132808142)
# Data is not normal
# SNJ O'Keefe
# NormaltestResult(statistic=12.670452180929418, pvalue=0.0017727449925475519)
# Data is not normal
# AC Agar
# NormaltestResult(statistic=5.581731252624415, pvalue=0.06136806910120067)
# Data may be normal
# BE Hendricks
# NormaltestResult(statistic=15.556407838319327, pvalue=0.0004187636329067721)
# Data is not normal
# A Nortje
# NormaltestResult(statistic=10.520724850924339, pvalue=0.005193422149157618)
# Data is not normal
# D Paterson
# NormaltestResult(statistic=15.414255183622394, pvalue=0.00044961109067787806)
# Data is not normal
# D Pretorius
# NormaltestResult(statistic=7.757129047346299, pvalue=0.02068049023904063)
# Data is not normal
# WPUJC Vaas
# NormaltestResult(statistic=31.139281069802315, pvalue=1.730577410394875e-07)
# Data is not normal
# SL Malinga
# NormaltestResult(statistic=23.595250988397765, pvalue=7.5223987045274454e-06)
# Data is not normal
# CRD Fernando
# NormaltestResult(statistic=15.004696137267953, pvalue=0.0005517872135886435)
# Data is not normal
# M Muralitharan
# NormaltestResult(statistic=59.12516121913887, pvalue=1.449220172010783e-13)
# Data is not normal
# MT Chinouya
# NormaltestResult(statistic=2.164559276499231, pvalue=0.33882225242176467)
# Data may be normal
# CJ Chibhabha
# NormaltestResult(statistic=0.7749449949303624, pvalue=0.6787703018985713)
# Data may be normal
# AG Cremer
# NormaltestResult(statistic=54.22529181484464, pvalue=1.6792969245116455e-12)
# Data is not normal
# J Nyumbu
# NormaltestResult(statistic=4.059767666925352, pvalue=0.13135077882741122)
# Data may be normal
# MJ Hoggard
# NormaltestResult(statistic=92.80142451082, pvalue=7.053857973732645e-21)
# Data is not normal
# A Flintoff
# NormaltestResult(statistic=41.04255707518756, pvalue=1.2238324645480835e-09)
# Data is not normal
# LE Plunkett
# NormaltestResult(statistic=7.018689568971888, pvalue=0.029916509777972496)
# Data is not normal
# SI Mahmood
# NormaltestResult(statistic=2.390830056261673, pvalue=0.302578349592364)
# Data may be normal
# M Labuschagne
# NormaltestResult(statistic=14.343322011366409, pvalue=0.000768045942468555)
# Data is not normal
# PM Pushpakumara
# NormaltestResult(statistic=94.14532000860218, pvalue=3.602496036107758e-21)
# Data is not normal
# PADLR Sandakan
# NormaltestResult(statistic=10.155719013086586, pvalue=0.0062332369495811555)
# Data is not normal
# MD Gunathilaka
# NormaltestResult(statistic=4.475010921407636, pvalue=0.106724400808502)
# Data may be normal
# Mohammad Abbas
# NormaltestResult(statistic=86.75273127702822, pvalue=1.451723002205438e-19)
# Data is not normal
# Asad Shafiq
# NormaltestResult(statistic=2.5544998559326344, pvalue=0.2788029754055678)
# Data may be normal
# Aizaz Cheema
# NormaltestResult(statistic=13.990537368402473, pvalue=0.0009162065896184822)
# Data is not normal
# Abdur Rehman
# NormaltestResult(statistic=122.32527554209187, pvalue=2.7378138577219344e-27)
# Data is not normal
# CJ Anderson
# NormaltestResult(statistic=5.67057851756799, pvalue=0.05870154344076318)
# Data may be normal
# N Deonarine
# NormaltestResult(statistic=65.76176542566884, pvalue=5.2482447222258414e-15)
# Data is not normal
# PT Collins
# NormaltestResult(statistic=6.036531830757734, pvalue=0.04888591722053661)
# Data is not normal
# RR Sarwan
# NormaltestResult(statistic=2.460491268448808, pvalue=0.29222078943742735)
# Data may be normal
# SJ Harmison
# NormaltestResult(statistic=25.66870302294823, pvalue=2.6675462609767514e-06)
# Data is not normal
# AF Giles
# NormaltestResult(statistic=6.861390976643276, pvalue=0.03236442386485682)
# Data is not normal
# IR Bell
# NormaltestResult(statistic=0.9478946135768413, pvalue=0.62254005533829)
# Data may be normal
# Kuldeep Yadav
# NormaltestResult(statistic=4.436629705863702, pvalue=0.10879228544269127)
# Data may be normal
# SR Harmer
# NormaltestResult(statistic=5.6109631549175605, pvalue=0.060477639490623805)
# Data may be normal
# S van Zyl
# NormaltestResult(statistic=15.263201579068248, pvalue=0.00048488403944888485)
# Data is not normal
# G Onions
# NormaltestResult(statistic=9.491896064933789, pvalue=0.008686822710888938)
# Data is not normal
# R Rampaul
# NormaltestResult(statistic=55.07494437062495, pvalue=1.0980643309910284e-12)
# Data is not normal
# RP Singh
# NormaltestResult(statistic=10.669047113911613, pvalue=0.004822207072059208)
# Data is not normal
# S Sreesanth
# NormaltestResult(statistic=40.47526659969585, pvalue=1.6252026847790687e-09)
# Data is not normal
# SK Raina
# NormaltestResult(statistic=6.9516426429767195, pvalue=0.030936414643826904)
# Data is not normal
# A Mishra
# NormaltestResult(statistic=40.77992155767652, pvalue=1.395572964388382e-09)
# Data is not normal
# JM Bird
# NormaltestResult(statistic=12.284117504788274, pvalue=0.0021504917277872272)
# Data is not normal
# T Panyangara
# NormaltestResult(statistic=8.899368081150456, pvalue=0.01168225750669673)
# Data is not normal
# E Chigumbura
# NormaltestResult(statistic=16.760592988987806, pvalue=0.0002293419367524191)
# Data is not normal
# N M'shangwe
# NormaltestResult(statistic=17.032217712120946, pvalue=0.00020021698469197886)
# Data is not normal
# Taskin Ahmed
# NormaltestResult(statistic=5.034831465486859, pvalue=0.08066780478053923)
# Data may be normal
# Kamrul Islam Rabbi
# NormaltestResult(statistic=7.533739431481918, pvalue=0.023124335855899385)
# Data is not normal
# Sabbir Rahman
# NormaltestResult(statistic=2.4357693287644526, pvalue=0.2958553388026024)
# Data may be normal
# Tanvir Ahmed (1)
# NormaltestResult(statistic=18.077514047530492, pvalue=0.00011871830881952225)
# Data is not normal
# L Sipamla
# NormaltestResult(statistic=2.892370229326369, pvalue=0.23546685591066974)
# Data may be normal
# PWA Mulder
# NormaltestResult(statistic=3.555522978640039, pvalue=0.16901606839473565)
# Data may be normal
# Mohammad Irfan
# NormaltestResult(statistic=14.984967914761462, pvalue=0.0005572570371743966)
# Data is not normal
# Zulfiqar Babar
# NormaltestResult(statistic=24.181183042314775, pvalue=5.612066640463828e-06)
# Data is not normal
# KA Jamieson
# NormaltestResult(statistic=5.743953309114886, pvalue=0.05658696308125556)
# Data may be normal
# WB Rankin
# NormaltestResult(statistic=25.929689325796375, pvalue=2.3412053300549337e-06)
# Data is not normal
# FDM Karunaratne
# NormaltestResult(statistic=5.175266374169679, pvalue=0.07519780877472633)
# Data may be normal
# UWMBCA Welegedara
# NormaltestResult(statistic=18.616898899818995, pvalue=9.065500137587136e-05)
# Data is not normal
# J Yadav
# NormaltestResult(statistic=3.761519453359425, pvalue=0.1524742230076622)
# Data may be normal
# Mustafizur Rahman
# NormaltestResult(statistic=10.449886946958829, pvalue=0.005380664101534805)
# Data is not normal
# Subashis Roy
# NormaltestResult(statistic=17.507413819211713, pvalue=0.0001578750106862058)
# Data is not normal
# KD Mills
# NormaltestResult(statistic=15.159021699213119, pvalue=0.000510811025328004)
# Data is not normal
# JDP Oram
# NormaltestResult(statistic=20.72915604568398, pvalue=3.1529781231913344e-05)
# Data is not normal
# Yuvraj Singh
# NormaltestResult(statistic=27.2046696714053, pvalue=1.2376021063783131e-06)
# Data is not normal
# JC Tredwell
# NormaltestResult(statistic=4.348580704032085, pvalue=0.1136888040812933)
# Data may be normal
# Ehsan Adil
# NormaltestResult(statistic=12.209924847812243, pvalue=0.0022317652295110197)
# Data is not normal
# Usman Shinwari
# NormaltestResult(statistic=2.2490409095818573, pvalue=0.3248081902287786)
# Data may be normal
# Naseem Shah
# NormaltestResult(statistic=8.746376514688889, pvalue=0.012610969388902297)
# Data is not normal
# Mahbubul Alam
# NormaltestResult(statistic=5.183583653646175, pvalue=0.07488573752463144)
# Data may be normal
# Mehrab Hossain jnr
# NormaltestResult(statistic=5.619272810777406, pvalue=0.060226886583244314)
# Data may be normal
# TS Roland-Jones
# NormaltestResult(statistic=1.4505833431784554, pvalue=0.484183325837937)
# Data may be normal
# SD Udal
# NormaltestResult(statistic=11.598469241035414, pvalue=0.0030298728606652204)
# Data is not normal
# Nasir Hossain
# NormaltestResult(statistic=16.027106416381656, pvalue=0.0003309467048162628)
# Data is not normal
# Suhrawadi Shuvo
# NormaltestResult(statistic=2.37226454331295, pvalue=0.3054001876809187)
# Data may be normal
# Naeem Islam
# NormaltestResult(statistic=3.075661351697356, pvalue=0.21484666832807325)
# Data may be normal
# JEC Franklin
# NormaltestResult(statistic=21.025224593210716, pvalue=2.7191332416453993e-05)
# Data is not normal
# NJ Astle
# NormaltestResult(statistic=6.282340430992916, pvalue=0.043232177325399204)
# Data is not normal
# MM Patel
# NormaltestResult(statistic=95.48988392470358, pvalue=1.8392262934947643e-21)
# Data is not normal
# KMA Paul
# NormaltestResult(statistic=7.745619738375114, pvalue=0.020799842400813055)
# Data is not normal
# SH Lewis
# NormaltestResult(statistic=3.438122957797753, pvalue=0.1792342841571708)
# Data may be normal
# SW Masakadza
# NormaltestResult(statistic=14.056159989380705, pvalue=0.0008866324864729314)
# Data is not normal
# Sohail Khan
# NormaltestResult(statistic=9.780715024295006, pvalue=0.0075187339557097445)
# Data is not normal
# Imran Khan (2)
# NormaltestResult(statistic=7.07529689637054, pvalue=0.029081633705954266)
# Data is not normal
# Fawad Alam
# NormaltestResult(statistic=1.4377117089367757, pvalue=0.48730949009631563)
# Data may be normal
# R McLaren
# NormaltestResult(statistic=2.3111701415073864, pvalue=0.3148732598656498)
# Data may be normal
# RJ Peterson
# NormaltestResult(statistic=17.1411076281332, pvalue=0.0001896076133658053)
# Data is not normal
# J Lewis
# NormaltestResult(statistic=2.0688424253885493, pvalue=0.355432040955856)
# Data may be normal
# A Mithun
# NormaltestResult(statistic=5.252264176906222, pvalue=0.07235779522452969)
# Data may be normal
# BP Martin
# NormaltestResult(statistic=14.286965135446545, pvalue=0.0007899960853858471)
# Data is not normal
# Yamin Ahmadzai
# NormaltestResult(statistic=17.814680595197306, pvalue=0.00013539145651431054)
# Data is not normal
# Wafadar Momand
# NormaltestResult(statistic=17.94348684201219, pvalue=0.00012694667761058652)
# Data is not normal
# Mohammad Nabi
# NormaltestResult(statistic=2.8455748715059643, pvalue=0.24104119276700067)
# Data may be normal
# Rashid Khan
# NormaltestResult(statistic=15.391244822595079, pvalue=0.00045481381921259884)
# Data is not normal
# Waqar Salamkheil
# NormaltestResult(statistic=8.501290250181771, pvalue=0.014255034661454056)
# Data is not normal
# WRS de Silva
# NormaltestResult(statistic=1.5131457333801785, pvalue=0.46927193176783943)
# Data may be normal
# MF Maharoof
# NormaltestResult(statistic=21.55573115214043, pvalue=2.0856068934676094e-05)
# Data is not normal
# Bilawal Bhatti
# NormaltestResult(statistic=7.902149038526627, pvalue=0.01923402333909857)
# Data is not normal
# DR Tuffey
# NormaltestResult(statistic=18.06796215011292, pvalue=0.00011928665749497873)
# Data is not normal
# Mohammad Shahid
# NormaltestResult(statistic=20.14408206572653, pvalue=4.224430387134262e-05)
# Data is not normal
# Shuvagata Hom
# NormaltestResult(statistic=12.264080434210669, pvalue=0.002172144789922486)
# Data is not normal
# Jubair Hossain
# NormaltestResult(statistic=2.085906676430385, pvalue=0.3524123506752378)
# Data may be normal
# LH Ferguson
# NormaltestResult(statistic=0.6898762208241734, pvalue=0.7082641862900115)
# Data may be normal
# JA Raval
# NormaltestResult(statistic=0.8201617350557848, pvalue=0.6635965845511366)
# Data may be normal
# DM Washington
# NormaltestResult(statistic=1.3258630872115345, pvalue=0.5153383809950325)
# Data may be normal
# IJL Trott
# NormaltestResult(statistic=4.02830549555251, pvalue=0.13343340723880318)
# Data may be normal
# CK Langeveldt
# NormaltestResult(statistic=2.5855805026416685, pvalue=0.2745037789883785)
# Data may be normal
# Syed Rasel
# NormaltestResult(statistic=3.135230066413177, pvalue=0.20854195536656386)
# Data may be normal
# Al-Amin Hossain
# NormaltestResult(statistic=10.284031570786032, pvalue=0.005845893761023137)
# Data is not normal
# DR Smith
# NormaltestResult(statistic=0.4917704916361571, pvalue=0.7820119589193019)
# Data may be normal
# D Olivier
# NormaltestResult(statistic=10.119250732145185, pvalue=0.006347937220148128)
# Data is not normal
# KMDN Kulasekara
# NormaltestResult(statistic=18.944250784185066, pvalue=7.696764708811892e-05)
# Data is not normal
# CJ Jordan
# NormaltestResult(statistic=5.821824261184101, pvalue=0.05442606354398266)
# Data may be normal
# JJ Krejza
# NormaltestResult(statistic=7.207999075123771, pvalue=0.027214658441213572)
# Data is not normal
# TJ Murtagh
# NormaltestResult(statistic=8.794085557046667, pvalue=0.012313700452907346)
# Data is not normal
# SR Thompson
# NormaltestResult(statistic=9.720683488116743, pvalue=0.007747835661851481)
# Data is not normal
# GC Tonge
# NormaltestResult(statistic=7.894178460058158, pvalue=0.019310829430831927)
# Data is not normal
# RS Bopara
# NormaltestResult(statistic=0.9144260841911314, pvalue=0.6330454603642789)
# Data may be normal
# SCG MacGill
# NormaltestResult(statistic=45.51472850905022, pvalue=1.3079835485769445e-10)
# Data is not normal
# MVT Fernando
# NormaltestResult(statistic=22.371524094391077, pvalue=1.3870281237101715e-05)
# Data is not normal
# TK Curran
# NormaltestResult(statistic=2.1368979437431226, pvalue=0.34354094607669156)
# Data may be normal
# Sohag Gazi
# NormaltestResult(statistic=68.11116996161346, pvalue=1.6212402035542292e-15)
# Data is not normal
# HMCM Bandara
# NormaltestResult(statistic=31.943389171562586, pvalue=1.157660392226653e-07)
# Data is not normal
# L Embuldeniya
# NormaltestResult(statistic=6.048807677211663, pvalue=0.04858677819908007)
# Data is not normal
# NLTC Perera
# NormaltestResult(statistic=5.139189050489097, pvalue=0.07656658494792203)
# Data may be normal
# AJ Hall
# NormaltestResult(statistic=15.70711853975854, pvalue=0.0003883672016526895)
# Data is not normal
# Ebadat Hossain
# NormaltestResult(statistic=3.8541770669590845, pvalue=0.1455714083857945)
# Data may be normal
# Abu Jayed
# NormaltestResult(statistic=15.984848368480783, pvalue=0.00033801368192231995)
# Data is not normal
# MD Shanaka
# NormaltestResult(statistic=4.4872003639667835, pvalue=0.10607592348346087)
# Data may be normal
# Shahid Afridi
# NormaltestResult(statistic=4.286193527133621, pvalue=0.11729105736026552)
# Data may be normal
# Imran Farhat
# NormaltestResult(statistic=2.000866503673656, pvalue=0.3677200912496393)
# Data may be normal
# Iftikhar Anjum
# NormaltestResult(statistic=0.8642363878243907, pvalue=0.6491326486235673)
# Data may be normal
# DM Bess
# NormaltestResult(statistic=11.113891756099337, pvalue=0.0038605489984167673)
# Data is not normal
# CR Brathwaite
# NormaltestResult(statistic=3.1541313623396894, pvalue=0.20658038242823337)
# Data may be normal
# WER Somerville
# NormaltestResult(statistic=5.411525604179341, pvalue=0.0668193344736992)
# Data may be normal
# CT Mumba
# NormaltestResult(statistic=41.549693437423954, pvalue=9.497268312727062e-10)
# Data is not normal
# SE Bond
# NormaltestResult(statistic=10.939580223304175, pvalue=0.004212116139322797)
# Data is not normal
# LL Tsotsobe
# NormaltestResult(statistic=2.098106751901706, pvalue=0.350269165438753)
# Data may be normal
# VRV Singh
# NormaltestResult(statistic=2.0317870809328724, pvalue=0.3620787532269084)
# Data may be normal
# GC Smith
# NormaltestResult(statistic=1.36870984838782, pvalue=0.5044155108902845)
# Data may be normal
# Iftikhar Ahmed
# NormaltestResult(statistic=2.141444862497492, pvalue=0.34276080683484417)
# Data may be normal
# TD Astle
# NormaltestResult(statistic=5.450821420231837, pvalue=0.0655192877570097)
# Data may be normal
# RK Kleinveldt
# NormaltestResult(statistic=8.592975350714644, pvalue=0.013616299988208964)
# Data is not normal
# PP Chawla
# NormaltestResult(statistic=3.5410551593733985, pvalue=0.17024314830163192)
# Data may be normal
# JL Gunn
# NormaltestResult(statistic=7.214967009745447, pvalue=0.027120008435330693)
# Data is not normal
# D Hazell
# NormaltestResult(statistic=16.039920739030208, pvalue=0.00032883305436920906)
# Data is not normal
# P Kumar
# NormaltestResult(statistic=14.572066314814787, pvalue=0.00068504011634648)
# Data is not normal
# Shadab Khan
# NormaltestResult(statistic=4.565395273802981, pvalue=0.10200865290423283)
# Data may be normal
# ST Jayasuriya
# NormaltestResult(statistic=0.56875728338838, pvalue=0.7524816698236059)
# Data may be normal
# Yasir Arafat
# NormaltestResult(statistic=6.843534889058469, pvalue=0.03265466858929614)
# Data is not normal
# P Utseya
# NormaltestResult(statistic=3.249551742108704, pvalue=0.19695581375652219)
# Data may be normal
# CH Morris
# NormaltestResult(statistic=7.520613388749165, pvalue=0.023276600477643905)
# Data is not normal
# C Green
# NormaltestResult(statistic=4.102931977435569, pvalue=0.12854631793755172)
# Data may be normal
# T Shamsi
# NormaltestResult(statistic=4.251769545618645, pvalue=0.11932734395750935)
# Data may be normal
# RA Reifer
# NormaltestResult(statistic=2.753913312229213, pvalue=0.2523453593466765)
# Data may be normal
# KK Peters
# NormaltestResult(statistic=3.160844808635011, pvalue=0.20588811180711147)
# Data may be normal
# Mohammad Sharif
# NormaltestResult(statistic=1.817055387046938, pvalue=0.4031172995429645)
# Data may be normal
# DE Bernard
# NormaltestResult(statistic=3.0241158996275006, pvalue=0.22045582378491496)
# Data may be normal
# RA Austin
# NormaltestResult(statistic=4.980061081472631, pvalue=0.08290743448241175)
# Data may be normal
# Muhammad Musa
# NormaltestResult(statistic=1.189150350705978, pvalue=0.5517969330191255)
# Data may be normal
# Nazmul Islam
# NormaltestResult(statistic=18.316875385547085, pvalue=0.00010532732321344607)
# Data is not normal
# J Botha
# NormaltestResult(statistic=4.027274973301408, pvalue=0.1335021780023322)
# Data may be normal
# S Muthusamy
# NormaltestResult(statistic=9.31310418346122, pvalue=0.009499158229423566)
# Data is not normal
# J Goswami
# NormaltestResult(statistic=2.960350265282346, pvalue=0.2275978250849999)
# Data may be normal
# N Niranjana
# NormaltestResult(statistic=5.792155482298168, pvalue=0.05523945916393556)
# Data may be normal
# BJ Arnel
# NormaltestResult(statistic=25.70195251687015, pvalue=2.6235655762109665e-06)
# Data is not normal
# BV Vitori
# NormaltestResult(statistic=3.6406582409613293, pvalue=0.161972433715229)
# Data may be normal
# JA Morkel
# NormaltestResult(statistic=4.399615295058056, pvalue=0.11082447367359706)
# Data may be normal
# Abul Hasan
# NormaltestResult(statistic=1.3617594427329518, pvalue=0.50617150655321)
# Data may be normal
# Elias Sunny
# NormaltestResult(statistic=1.6954633783925872, pvalue=0.42838554226329484)
# Data may be normal
# B Muzarabani
# NormaltestResult(statistic=2.299255805671375, pvalue=0.31675461094595314)
# Data may be normal
# MS Dhoni
# NormaltestResult(statistic=1.706884501393949, pvalue=0.425946191937262)
# Data may be normal
# C Munro
# NormaltestResult(statistic=7.870943729724198, pvalue=0.019536478574402733)
# Data is not normal
# SC Kerrigan
# NormaltestResult(statistic=6.2727322088521715, pvalue=0.04344036919510421)
# Data is not normal
# JT Ball
# NormaltestResult(statistic=9.190666362093003, pvalue=0.010098855473146557)
# Data is not normal
# MR Gillespie
# NormaltestResult(statistic=16.218141046789313, pvalue=0.0003007983283068201)
# Data is not normal
# M Zondeki
# NormaltestResult(statistic=14.691124080385165, pvalue=0.0006454504968798475)
# Data is not normal
# MJ Leach
# NormaltestResult(statistic=2.43333265660816, pvalue=0.296216009700348)
# Data may be normal
# HH Streak
# NormaltestResult(statistic=4.825409144744958, pvalue=0.08957271079847694)
# Data may be normal
# NB Mahwire
# NormaltestResult(statistic=2.7483910640676, pvalue=0.2530430789970393)
# Data may be normal
# SP Jones
# NormaltestResult(statistic=1.7395345071171728, pvalue=0.4190490700782241)
# Data may be normal
# Mohammad Talha
# NormaltestResult(statistic=3.387786863140689, pvalue=0.18380250658779157)
# Data may be normal
# Mohammed Siraj
# NormaltestResult(statistic=14.822231005329172, pvalue=0.0006044960013937308)
# Data is not normal
# GF Linde
# NormaltestResult(statistic=20.67098824550754, pvalue=3.246025556261298e-05)
# Data is not normal
# GB Hogg
# NormaltestResult(statistic=27.73306281174334, pvalue=9.502588594172143e-07)
# Data is not normal
# Faheem Ashraf
# NormaltestResult(statistic=4.125609853946967, pvalue=0.12709697172773968)
# Data may be normal
# JW Hastings
# NormaltestResult(statistic=22.07772600767764, pvalue=1.6065073281590495e-05)
# Data is not normal
# NA Saini
# NormaltestResult(statistic=5.372846711739751, pvalue=0.0681241600327065)
# Data may be normal
# TE Kane
# NormaltestResult(statistic=10.51240039643601, pvalue=0.005215083400570812)
# Data is not normal
# NT Pascal
# NormaltestResult(statistic=1.697263980683506, pvalue=0.4280000398290773)
# Data may be normal
# KO Meth
# NormaltestResult(statistic=3.951633862275673, pvalue=0.13864800009666908)
# Data may be normal
# SW Tait
# NormaltestResult(statistic=4.839458174909907, pvalue=0.08894571070451578)
# Data may be normal
# CJ Sayers
# NormaltestResult(statistic=1.7966707590738453, pvalue=0.40724700752295073)
# Data may be normal
# SS Cottrell
# NormaltestResult(statistic=1.0209845527523793, pvalue=0.6002000417737298)
# Data may be normal
# Mujeeb Ur Rahman
# NormaltestResult(statistic=7.209888655025523, pvalue=0.027188958447861237)
# Data is not normal
# JA Richardson
# NormaltestResult(statistic=1.9552131717621448, pvalue=0.3762104495644055)
# Data may be normal
# C Karunaratne
# NormaltestResult(statistic=0.3091757945121062, pvalue=0.8567681812601289)
# Data may be normal
# KL Cross
# NormaltestResult(statistic=1.0499870977524475, pvalue=0.5915591805760005)
# Data may be normal
# HC Knight
# NormaltestResult(statistic=16.51702554491453, pvalue=0.0002590439621967452)
# Data is not normal
# 295 129

# %%
#Shapiro-Wilk Test

notnormcount = 0
maybenormcount = 0

for name in bdfdict:
    
    if(len(bdfdict[name]['runs'])>=8):
        
        print(name)
        print(scipy.stats.shapiro(bdfdict[name]['runs']))
        
        if(scipy.stats.shapiro(bdfdict[name]['runs'])[1] < 0.05):
            print("Data is not normal")
            notnormcount += 1
        else:
            print("Data may be normal")
            maybenormcount += 1
print(notnormcount, maybenormcount)
# Out:
# B Lee
# ShapiroResult(statistic=0.909936249256134, pvalue=5.346957685642417e-13)
# Data is not normal
# PM Siddle
# ShapiroResult(statistic=0.8772783875465393, pvalue=3.895804196448819e-21)
# Data is not normal
# MG Johnson
# ShapiroResult(statistic=0.9065262079238892, pvalue=1.8387207584900365e-17)
# Data is not normal
# SR Watson
# ShapiroResult(statistic=0.8885559439659119, pvalue=7.338306351467594e-11)
# Data is not normal
# MJ Clarke
# ShapiroResult(statistic=0.9257700443267822, pvalue=7.75795997469686e-05)
# Data is not normal
# CL White
# ShapiroResult(statistic=0.9136312007904053, pvalue=0.002935657976195216)
# Data is not normal
# JM Anderson
# ShapiroResult(statistic=0.8797075152397156, pvalue=2.6596984974254627e-32)
# Data is not normal
# SCJ Broad
# ShapiroResult(statistic=0.8940274715423584, pvalue=2.416853098330188e-29)
# Data is not normal
# MS Panesar
# ShapiroResult(statistic=0.8565459251403809, pvalue=1.838950940882525e-20)
# Data is not normal
# GP Swann
# ShapiroResult(statistic=0.8664339780807495, pvalue=8.639844447695708e-24)
# Data is not normal
# SR Patel
# ShapiroResult(statistic=0.8297542333602905, pvalue=2.326926740181534e-08)
# Data is not normal
# KM Jarvis
# ShapiroResult(statistic=0.8919579386711121, pvalue=7.438094140610474e-09)
# Data is not normal
# TL Chatara
# ShapiroResult(statistic=0.8736169338226318, pvalue=3.5646557989821304e-06)
# Data is not normal
# DT Tiripano
# ShapiroResult(statistic=0.9272425174713135, pvalue=1.909407183120493e-05)
# Data is not normal
# Sikandar Raza
# ShapiroResult(statistic=0.9190388321876526, pvalue=3.533941344358027e-05)
# Data is not normal
# SC Williams
# ShapiroResult(statistic=0.8459703326225281, pvalue=1.1882402617402477e-07)
# Data is not normal
# B Mavuta
# ShapiroResult(statistic=0.9360537528991699, pvalue=0.06421645730733871)
# Data may be normal
# H Masakadza
# ShapiroResult(statistic=0.840256929397583, pvalue=2.4735868464631494e-07)
# Data is not normal
# BW Hilfenhaus
# ShapiroResult(statistic=0.8788263201713562, pvalue=6.234151649769926e-12)
# Data is not normal
# XJ Doherty
# ShapiroResult(statistic=0.8226309418678284, pvalue=0.012822140008211136)
# Data is not normal
# MJ North
# ShapiroResult(statistic=0.9284798502922058, pvalue=0.03553037717938423)
# Data is not normal
# CT Tremlett
# ShapiroResult(statistic=0.8750960826873779, pvalue=1.6455611873134046e-10)
# Data is not normal
# TT Bresnan
# ShapiroResult(statistic=0.8934271335601807, pvalue=2.5568075759895004e-13)
# Data is not normal
# MA Starc
# ShapiroResult(statistic=0.9181926846504211, pvalue=2.4476600234605435e-17)
# Data is not normal
# NM Lyon
# ShapiroResult(statistic=0.884961724281311, pvalue=8.084153534288615e-28)
# Data is not normal
# MR Marsh
# ShapiroResult(statistic=0.8542997241020203, pvalue=6.3727560555004725e-12)
# Data is not normal
# GJ Maxwell
# ShapiroResult(statistic=0.9301239252090454, pvalue=0.08748333156108856)
# Data may be normal
# SPD Smith
# ShapiroResult(statistic=0.8247473239898682, pvalue=8.722506208869163e-06)
# Data is not normal
# MA Wood
# ShapiroResult(statistic=0.8782105445861816, pvalue=7.001221380420475e-09)
# Data is not normal
# BA Stokes
# ShapiroResult(statistic=0.9098984599113464, pvalue=2.748337522528164e-15)
# Data is not normal
# ST Finn
# ShapiroResult(statistic=0.9212389588356018, pvalue=1.6128714683261158e-11)
# Data is not normal
# MM Ali
# ShapiroResult(statistic=0.9201651811599731, pvalue=1.3097214285329173e-12)
# Data is not normal
# JE Root
# ShapiroResult(statistic=0.922741174697876, pvalue=0.0009905108017846942)
# Data is not normal
# DW Steyn
# ShapiroResult(statistic=0.8892307281494141, pvalue=7.412680393405098e-25)
# Data is not normal
# M Morkel
# ShapiroResult(statistic=0.8857806324958801, pvalue=3.942358011821426e-24)
# Data is not normal
# M de Lange
# ShapiroResult(statistic=0.8594372272491455, pvalue=0.0040537528693675995)
# Data is not normal
# Imran Tahir
# ShapiroResult(statistic=0.9058843851089478, pvalue=1.569875673901322e-09)
# Data is not normal
# JH Kallis
# ShapiroResult(statistic=0.9014326930046082, pvalue=1.3840900846450512e-16)
# Data is not normal
# Taijul Islam
# ShapiroResult(statistic=0.8663238883018494, pvalue=5.107643310131582e-19)
# Data is not normal
# Shakib Al Hasan
# ShapiroResult(statistic=0.8772042989730835, pvalue=1.4162694355027842e-23)
# Data is not normal
# Mehedi Hasan Miraz
# ShapiroResult(statistic=0.8846083879470825, pvalue=1.2998568963817209e-13)
# Data is not normal
# Nayeem Hasan
# ShapiroResult(statistic=0.8573471307754517, pvalue=2.0892661268590018e-05)
# Data is not normal
# Mahmudullah
# ShapiroResult(statistic=0.9004644751548767, pvalue=5.5591971998003586e-11)
# Data is not normal
# Soumya Sarkar
# ShapiroResult(statistic=0.9281896948814392, pvalue=0.02771558240056038)
# Data is not normal
# Mominul Haque
# ShapiroResult(statistic=0.8198770880699158, pvalue=0.0006340011022984982)
# Data is not normal
# B Kumar
# ShapiroResult(statistic=0.8804173469543457, pvalue=1.9703421186290093e-11)
# Data is not normal
# Mohammed Shami
# ShapiroResult(statistic=0.918197512626648, pvalue=7.944799738880334e-14)
# Data is not normal
# R Ashwin
# ShapiroResult(statistic=0.8806111812591553, pvalue=1.4414083408381838e-26)
# Data is not normal
# PP Ojha
# ShapiroResult(statistic=0.8758407831192017, pvalue=3.3887951490943777e-20)
# Data is not normal
# SR Tendulkar
# ShapiroResult(statistic=0.9215420484542847, pvalue=0.06318355351686478)
# Data may be normal
# Z Khan
# ShapiroResult(statistic=0.9035634994506836, pvalue=6.892331235142371e-20)
# Data is not normal
# I Sharma
# ShapiroResult(statistic=0.8724023699760437, pvalue=4.499136535616342e-28)
# Data is not normal
# Harbhajan Singh
# ShapiroResult(statistic=0.8701350092887878, pvalue=4.222022468527732e-27)
# Data is not normal
# V Sehwag
# ShapiroResult(statistic=0.9145053029060364, pvalue=2.9680828461664532e-08)
# Data is not normal
# RAS Lakmal
# ShapiroResult(statistic=0.8609727621078491, pvalue=3.169337985779886e-23)
# Data is not normal
# RMS Eranga
# ShapiroResult(statistic=0.9022366404533386, pvalue=9.256476878397035e-13)
# Data is not normal
# AD Mathews
# ShapiroResult(statistic=0.8814548850059509, pvalue=8.219176580385578e-15)
# Data is not normal
# KTGD Prasad
# ShapiroResult(statistic=0.951347827911377, pvalue=1.5872607264100225e-06)
# Data is not normal
# PHT Kaushal
# ShapiroResult(statistic=0.9146372079849243, pvalue=0.00010048030526377261)
# Data is not normal
# JL Pattinson
# ShapiroResult(statistic=0.9196206331253052, pvalue=2.9622029273923545e-07)
# Data is not normal
# MEK Hussey
# ShapiroResult(statistic=0.9267677664756775, pvalue=0.1703166961669922)
# Data may be normal
# Shafiul Islam
# ShapiroResult(statistic=0.9207530617713928, pvalue=3.780645556616946e-07)
# Data is not normal
# Robiul Islam
# ShapiroResult(statistic=0.8924587368965149, pvalue=3.798578518399154e-08)
# Data is not normal
# Rubel Hossain
# ShapiroResult(statistic=0.9097343683242798, pvalue=2.0966490696383566e-11)
# Data is not normal
# Abdur Razzak
# ShapiroResult(statistic=0.8772038817405701, pvalue=4.314550453021759e-12)
# Data is not normal
# FH Edwards
# ShapiroResult(statistic=0.9253952503204346, pvalue=2.9294459653189664e-13)
# Data is not normal
# TL Best
# ShapiroResult(statistic=0.9263036251068115, pvalue=7.461467816938239e-07)
# Data is not normal
# DJG Sammy
# ShapiroResult(statistic=0.879817545413971, pvalue=7.142060050262093e-17)
# Data is not normal
# SP Narine
# ShapiroResult(statistic=0.8929338455200195, pvalue=2.47919933826779e-06)
# Data is not normal
# V Permaul
# ShapiroResult(statistic=0.904833972454071, pvalue=4.287334741093218e-05)
# Data is not normal
# MN Samuels
# ShapiroResult(statistic=0.9111802577972412, pvalue=7.867592799470913e-09)
# Data is not normal
# JC Archer
# ShapiroResult(statistic=0.8752042651176453, pvalue=2.699557732910307e-08)
# Data is not normal
# CR Woakes
# ShapiroResult(statistic=0.8760331273078918, pvalue=1.2828210648146814e-14)
# Data is not normal
# SM Curran
# ShapiroResult(statistic=0.8909939527511597, pvalue=2.5768811156012816e-06)
# Data is not normal
# JL Denly
# ShapiroResult(statistic=0.8901596069335938, pvalue=0.1397085338830948)
# Data may be normal
# JJ Bumrah
# ShapiroResult(statistic=0.8409030437469482, pvalue=8.167080726984022e-12)
# Data is not normal
# GH Vihari
# ShapiroResult(statistic=0.9167302250862122, pvalue=0.17170275747776031)
# Data may be normal
# RA Jadeja
# ShapiroResult(statistic=0.8442787528038025, pvalue=5.531949575646039e-23)
# Data is not normal
# Mohammad Sami
# ShapiroResult(statistic=0.9296823740005493, pvalue=4.3040759578616417e-07)
# Data is not normal
# Umar Gul
# ShapiroResult(statistic=0.8867553472518921, pvalue=2.418868365973986e-21)
# Data is not normal
# Shahid Nazir
# ShapiroResult(statistic=0.8565512895584106, pvalue=1.4345660019898787e-05)
# Data is not normal
# Danish Kaneria
# ShapiroResult(statistic=0.9128475189208984, pvalue=2.2244466917393135e-16)
# Data is not normal
# Salman Butt
# ShapiroResult(statistic=0.9408717155456543, pvalue=0.22671794891357422)
# Data may be normal
# TA Boult
# ShapiroResult(statistic=0.8865635991096497, pvalue=8.266325021353188e-25)
# Data is not normal
# TG Southee
# ShapiroResult(statistic=0.8927836418151855, pvalue=1.66133491328039e-23)
# Data is not normal
# C de Grandhomme
# ShapiroResult(statistic=0.8654488921165466, pvalue=3.0420557261092492e-15)
# Data is not normal
# N Wagner
# ShapiroResult(statistic=0.8812902569770813, pvalue=2.550452434935866e-22)
# Data is not normal
# AY Patel
# ShapiroResult(statistic=0.9004790186882019, pvalue=0.00012084675836376846)
# Data is not normal
# Mohammad Asif
# ShapiroResult(statistic=0.9037084579467773, pvalue=1.0806893574466514e-13)
# Data is not normal
# KAJ Roach
# ShapiroResult(statistic=0.8876410722732544, pvalue=4.015269664277836e-24)
# Data is not normal
# JO Holder
# ShapiroResult(statistic=0.861259400844574, pvalue=1.4549366833952042e-22)
# Data is not normal
# RRS Cornwall
# ShapiroResult(statistic=0.8374218940734863, pvalue=1.0434096253675307e-08)
# Data is not normal
# JA Warrican
# ShapiroResult(statistic=0.8598370552062988, pvalue=2.7391286461231346e-10)
# Data is not normal
# RL Chase
# ShapiroResult(statistic=0.8994936347007751, pvalue=1.5673326925915143e-16)
# Data is not normal
# T Thushara
# ShapiroResult(statistic=0.9106282591819763, pvalue=0.001244907733052969)
# Data is not normal
# BAW Mendis
# ShapiroResult(statistic=0.8971643447875977, pvalue=4.137015729988036e-10)
# Data is not normal
# S Randiv
# ShapiroResult(statistic=0.846850574016571, pvalue=1.2122329182129299e-11)
# Data is not normal
# TM Dilshan
# ShapiroResult(statistic=0.8802692890167236, pvalue=1.0656212907633744e-06)
# Data is not normal
# N Pradeep
# ShapiroResult(statistic=0.9183401465415955, pvalue=3.088904566156403e-12)
# Data is not normal
# PVD Chameera
# ShapiroResult(statistic=0.9355393648147583, pvalue=0.00025865889620035887)
# Data is not normal
# HMRKB Herath
# ShapiroResult(statistic=0.8920379877090454, pvalue=7.546372841836462e-26)
# Data is not normal
# TAM Siriwardana
# ShapiroResult(statistic=0.9308757781982422, pvalue=0.3894869387149811)
# Data may be normal
# JS Patel
# ShapiroResult(statistic=0.8724112510681152, pvalue=1.571613898862425e-14)
# Data is not normal
# MJ Santner
# ShapiroResult(statistic=0.8934202194213867, pvalue=6.28358476362223e-12)
# Data is not normal
# JDS Neesham
# ShapiroResult(statistic=0.8965502977371216, pvalue=0.00024691520957276225)
# Data is not normal
# KJ Abbott
# ShapiroResult(statistic=0.8483041524887085, pvalue=4.20731680605968e-08)
# Data is not normal
# DL Piedt
# ShapiroResult(statistic=0.899093747138977, pvalue=3.071205156857104e-08)
# Data is not normal
# D Elgar
# ShapiroResult(statistic=0.9571016430854797, pvalue=0.009589916095137596)
# Data is not normal
# JP Duminy
# ShapiroResult(statistic=0.869019627571106, pvalue=4.974864520335132e-09)
# Data is not normal
# UT Yadav
# ShapiroResult(statistic=0.9307857155799866, pvalue=9.791039506934496e-13)
# Data is not normal
# M Vijay
# ShapiroResult(statistic=0.8661278486251831, pvalue=0.0066366191022098064)
# Data is not normal
# ST Gabriel
# ShapiroResult(statistic=0.9153256416320801, pvalue=5.331392046911996e-18)
# Data is not normal
# AS Joseph
# ShapiroResult(statistic=0.8976851105690002, pvalue=1.2391469794703625e-10)
# Data is not normal
# CK Holder
# ShapiroResult(statistic=0.9062521457672119, pvalue=0.021651502698659897)
# Data is not normal
# ZS Ansari
# ShapiroResult(statistic=0.862055778503418, pvalue=0.013197265565395355)
# Data is not normal
# AU Rashid
# ShapiroResult(statistic=0.8956624865531921, pvalue=3.166530149201208e-08)
# Data is not normal
# DBL Powell
# ShapiroResult(statistic=0.9178155660629272, pvalue=3.822169143685716e-12)
# Data is not normal
# LS Baker
# ShapiroResult(statistic=0.8858667612075806, pvalue=4.6642353481729515e-06)
# Data is not normal
# BP Nash
# ShapiroResult(statistic=0.8997021317481995, pvalue=0.00046972991549409926)
# Data is not normal
# CH Gayle
# ShapiroResult(statistic=0.8701083660125732, pvalue=7.393335211625454e-14)
# Data is not normal
# RO Hinds
# ShapiroResult(statistic=0.9049535393714905, pvalue=2.4735556507948786e-05)
# Data is not normal
# LMP Simmons
# ShapiroResult(statistic=0.9209847450256348, pvalue=0.0474189929664135)
# Data is not normal
# Junaid Khan
# ShapiroResult(statistic=0.8950327038764954, pvalue=3.9966199295339566e-13)
# Data is not normal
# Rahat Ali
# ShapiroResult(statistic=0.9121359586715698, pvalue=1.6036930672314043e-09)
# Data is not normal
# Saeed Ajmal
# ShapiroResult(statistic=0.8893353343009949, pvalue=5.322862308261572e-22)
# Data is not normal
# Younis Khan
# ShapiroResult(statistic=0.9463182091712952, pvalue=0.04379664734005928)
# Data is not normal
# Mohammad Hafeez
# ShapiroResult(statistic=0.8865698575973511, pvalue=1.887322742533115e-09)
# Data is not normal
# SR Clark
# ShapiroResult(statistic=0.8967937231063843, pvalue=1.2809760847540264e-12)
# Data is not normal
# MS Kasprowicz
# ShapiroResult(statistic=0.9074077606201172, pvalue=0.00019504585361573845)
# Data is not normal
# SK Warne
# ShapiroResult(statistic=0.912015974521637, pvalue=3.752548549673662e-10)
# Data is not normal
# A Symonds
# ShapiroResult(statistic=0.8837969303131104, pvalue=5.791494572804368e-07)
# Data is not normal
# Shahadat Hossain
# ShapiroResult(statistic=0.9298522472381592, pvalue=1.209069511176608e-10)
# Data is not normal
# Enamul Haque jnr
# ShapiroResult(statistic=0.9169192910194397, pvalue=1.2366378996375715e-06)
# Data is not normal
# Mohammad Ashraful
# ShapiroResult(statistic=0.9349543452262878, pvalue=0.05390671268105507)
# Data may be normal
# MJ Henry
# ShapiroResult(statistic=0.8944802284240723, pvalue=1.2236341107030313e-10)
# Data is not normal
# DAJ Bracewell
# ShapiroResult(statistic=0.906646728515625, pvalue=2.316185090944778e-11)
# Data is not normal
# MD Craig
# ShapiroResult(statistic=0.9206828474998474, pvalue=1.4880427556818177e-07)
# Data is not normal
# KS Williamson
# ShapiroResult(statistic=0.8724561333656311, pvalue=1.6735938288547914e-06)
# Data is not normal
# BB McCullum
# ShapiroResult(statistic=0.8776195049285889, pvalue=0.08170939981937408)
# Data may be normal
# C Overton
# ShapiroResult(statistic=0.887638509273529, pvalue=4.199374234303832e-05)
# Data is not normal
# CBRLS Kumara
# ShapiroResult(statistic=0.9143357276916504, pvalue=2.3148033836961623e-11)
# Data is not normal
# CAK Rajitha
# ShapiroResult(statistic=0.9210051894187927, pvalue=1.2134230019000825e-05)
# Data is not normal
# MDK Perera
# ShapiroResult(statistic=0.9085955619812012, pvalue=1.4453683391070287e-15)
# Data is not normal
# GD McGrath
# ShapiroResult(statistic=0.8415189385414124, pvalue=1.5082679029332358e-12)
# Data is not normal
# JN Gillespie
# ShapiroResult(statistic=0.8472763895988464, pvalue=9.317325748270378e-06)
# Data is not normal
# M Ntini
# ShapiroResult(statistic=0.903062641620636, pvalue=3.388532475305922e-17)
# Data is not normal
# PL Harris
# ShapiroResult(statistic=0.798225998878479, pvalue=1.2211966202116632e-18)
# Data is not normal
# CS Martin
# ShapiroResult(statistic=0.9007434844970703, pvalue=3.5511591615840525e-17)
# Data is not normal
# IE O'Brien
# ShapiroResult(statistic=0.8861978650093079, pvalue=3.34573792282189e-11)
# Data is not normal
# GD Elliott
# ShapiroResult(statistic=0.8343720436096191, pvalue=0.0029492569155991077)
# Data is not normal
# DL Vettori
# ShapiroResult(statistic=0.8398277759552002, pvalue=3.140789488273172e-22)
# Data is not normal
# JD Ryder
# ShapiroResult(statistic=0.8742160797119141, pvalue=0.001454652869142592)
# Data is not normal
# KC Brathwaite
# ShapiroResult(statistic=0.7976111769676208, pvalue=2.1866465547428458e-14)
# Data is not normal
# KH Brunt
# ShapiroResult(statistic=0.8312983512878418, pvalue=2.4556004518672125e-07)
# Data is not normal
# A Shrubsole
# ShapiroResult(statistic=0.8599965572357178, pvalue=9.245832188753411e-07)
# Data is not normal
# S Ecclestone
# ShapiroResult(statistic=0.8849740028381348, pvalue=0.00188258767593652)
# Data is not normal
# NR Sciver
# ShapiroResult(statistic=0.9247140884399414, pvalue=0.25688448548316956)
# Data may be normal
# KL Gordon
# ShapiroResult(statistic=0.9048351645469666, pvalue=0.01728673093020916)
# Data is not normal
# LA Marsh
# ShapiroResult(statistic=0.9122104644775391, pvalue=3.740459942491725e-05)
# Data is not normal
# JE Taylor
# ShapiroResult(statistic=0.9133670330047607, pvalue=3.810716857274617e-18)
# Data is not normal
# J Blackwood
# ShapiroResult(statistic=0.8615754842758179, pvalue=0.025431299582123756)
# Data is not normal
# Pankaj Singh
# ShapiroResult(statistic=0.8084452152252197, pvalue=1.935810905706603e-05)
# Data is not normal
# RG Sharma
# ShapiroResult(statistic=0.8646512627601624, pvalue=0.055927302688360214)
# Data may be normal
# NM Hauritz
# ShapiroResult(statistic=0.8197646737098694, pvalue=1.1402740973665004e-08)
# Data is not normal
# SM Katich
# ShapiroResult(statistic=0.8635978698730469, pvalue=0.009085346944630146)
# Data is not normal
# Shoaib Akhtar
# ShapiroResult(statistic=0.9133089780807495, pvalue=0.0025272220373153687)
# Data is not normal
# Sohail Tanvir
# ShapiroResult(statistic=0.849535346031189, pvalue=0.00010547669080551714)
# Data is not normal
# Yasir Hameed
# ShapiroResult(statistic=0.9217150211334229, pvalue=0.30043846368789673)
# Data may be normal
# Mashrafe Mortaza
# ShapiroResult(statistic=0.8872281312942505, pvalue=1.2903015544907248e-08)
# Data is not normal
# Mohammad Rafique
# ShapiroResult(statistic=0.8876794576644897, pvalue=1.0227178215416188e-08)
# Data is not normal
# Aftab Ahmed
# ShapiroResult(statistic=0.7836726307868958, pvalue=0.0009012914379127324)
# Data is not normal
# RJ Harris
# ShapiroResult(statistic=0.8607836961746216, pvalue=5.722021814702494e-11)
# Data is not normal
# TA Copeland
# ShapiroResult(statistic=0.7601589560508728, pvalue=0.0034187196288257837)
# Data is not normal
# VR Aaron
# ShapiroResult(statistic=0.8961946368217468, pvalue=2.4381293769693002e-05)
# Data is not normal
# KV Sharma
# ShapiroResult(statistic=0.8739759922027588, pvalue=0.0014359750784933567)
# Data is not normal
# VD Philander
# ShapiroResult(statistic=0.866195797920227, pvalue=4.578342100698006e-21)
# Data is not normal
# A Dananjaya
# ShapiroResult(statistic=0.902842104434967, pvalue=0.00010258169641019776)
# Data is not normal
# DM de Silva
# ShapiroResult(statistic=0.9356429576873779, pvalue=9.700484042696189e-06)
# Data is not normal
# D Bishoo
# ShapiroResult(statistic=0.926577091217041, pvalue=2.4957102424711004e-14)
# Data is not normal
# IS Sodhi
# ShapiroResult(statistic=0.8888770341873169, pvalue=1.9200947498632104e-09)
# Data is not normal
# KA Maharaj
# ShapiroResult(statistic=0.8653505444526672, pvalue=2.8022089486680743e-18)
# Data is not normal
# K Rabada
# ShapiroResult(statistic=0.8995208740234375, pvalue=8.489386655065041e-16)
# Data is not normal
# AK Markram
# ShapiroResult(statistic=0.729238748550415, pvalue=0.0016361442394554615)
# Data is not normal
# TB de Bruyn
# ShapiroResult(statistic=0.9202308654785156, pvalue=0.2878304421901703)
# Data may be normal
# DA Warner
# ShapiroResult(statistic=0.9371545314788818, pvalue=0.3156082034111023)
# Data may be normal
# SJ Benn
# ShapiroResult(statistic=0.8732715845108032, pvalue=1.5710186384493072e-21)
# Data is not normal
# S Shillingford
# ShapiroResult(statistic=0.8374010324478149, pvalue=4.773276227022334e-19)
# Data is not normal
# ML Cummins
# ShapiroResult(statistic=0.9290555119514465, pvalue=1.5391077567983302e-06)
# Data is not normal
# CD Collymore
# ShapiroResult(statistic=0.8757456541061401, pvalue=8.056956490865019e-11)
# Data is not normal
# DJ Bravo
# ShapiroResult(statistic=0.8984097242355347, pvalue=2.8296958841448868e-15)
# Data is not normal
# D Mohammed
# ShapiroResult(statistic=0.9103533029556274, pvalue=0.08727634698152542)
# Data may be normal
# N Ncube
# ShapiroResult(statistic=0.9242550134658813, pvalue=0.0640944316983223)
# Data may be normal
# CB Mpofu
# ShapiroResult(statistic=0.8995985388755798, pvalue=7.363783538494317e-08)
# Data is not normal
# RW Price
# ShapiroResult(statistic=0.8762813806533813, pvalue=0.00030225387308746576)
# Data is not normal
# MN Waller
# ShapiroResult(statistic=0.8484747409820557, pvalue=0.0001450358104193583)
# Data is not normal
# SM Pollock
# ShapiroResult(statistic=0.8278291821479797, pvalue=4.920109111794524e-11)
# Data is not normal
# A Nel
# ShapiroResult(statistic=0.8664130568504333, pvalue=4.965415014920871e-13)
# Data is not normal
# N Boje
# ShapiroResult(statistic=0.8947703838348389, pvalue=7.283226750587346e-07)
# Data is not normal
# HH Pandya
# ShapiroResult(statistic=0.9221151471138, pvalue=0.004444649443030357)
# Data is not normal
# DE Bollinger
# ShapiroResult(statistic=0.8177405595779419, pvalue=0.0004561746318358928)
# Data is not normal
# PLS Gamage
# ShapiroResult(statistic=0.8788442611694336, pvalue=8.12516373116523e-06)
# Data is not normal
# IDR Bradshaw
# ShapiroResult(statistic=0.8384777903556824, pvalue=1.878195661220161e-07)
# Data is not normal
# RJ Sidebottom
# ShapiroResult(statistic=0.8906989097595215, pvalue=7.215994468623421e-11)
# Data is not normal
# PD Collingwood
# ShapiroResult(statistic=0.8951429128646851, pvalue=4.1045743273571134e-05)
# Data is not normal
# KP Pietersen
# ShapiroResult(statistic=0.922371506690979, pvalue=0.0050917621701955795)
# Data is not normal
# HK Bennett
# ShapiroResult(statistic=0.8698961138725281, pvalue=0.0336226224899292)
# Data is not normal
# IK Pathan
# ShapiroResult(statistic=0.8370462656021118, pvalue=2.148929922896059e-09)
# Data is not normal
# SC Ganguly
# ShapiroResult(statistic=0.869154155254364, pvalue=1.8293512766831554e-05)
# Data is not normal
# A Kumble
# ShapiroResult(statistic=0.898651123046875, pvalue=1.2670837326382003e-16)
# Data is not normal
# Mohammad Amir
# ShapiroResult(statistic=0.9033998847007751, pvalue=1.6438069298854708e-16)
# Data is not normal
# Abdur Rauf
# ShapiroResult(statistic=0.9517527222633362, pvalue=0.11874350160360336)
# Data may be normal
# Shoaib Malik
# ShapiroResult(statistic=0.9409554600715637, pvalue=0.00020427197159733623)
# Data is not normal
# L Ngidi
# ShapiroResult(statistic=0.9012969732284546, pvalue=4.159866875852458e-06)
# Data is not normal
# JR Hazlewood
# ShapiroResult(statistic=0.8633726239204407, pvalue=1.2030088919813062e-21)
# Data is not normal
# PJ Cummins
# ShapiroResult(statistic=0.8887560367584229, pvalue=7.677480164133377e-16)
# Data is not normal
# Wahab Riaz
# ShapiroResult(statistic=0.9066312909126282, pvalue=9.716791986909973e-14)
# Data is not normal
# Yasir Shah
# ShapiroResult(statistic=0.8989059925079346, pvalue=2.065611514977839e-20)
# Data is not normal
# Azhar Ali
# ShapiroResult(statistic=0.9026413559913635, pvalue=0.00011378192721167579)
# Data is not normal
# Shan Masood
# ShapiroResult(statistic=0.8248677849769592, pvalue=0.029017115011811256)
# Data is not normal
# AS Jaggernauth
# ShapiroResult(statistic=0.9061672687530518, pvalue=0.05389564484357834)
# Data may be normal
# Abdul Razzaq
# ShapiroResult(statistic=0.9032014608383179, pvalue=0.0015667740954086185)
# Data is not normal
# JM Holland
# ShapiroResult(statistic=0.9185501337051392, pvalue=2.070012124022469e-05)
# Data is not normal
# Hasan Ali
# ShapiroResult(statistic=0.9117894768714905, pvalue=8.626529961475171e-06)
# Data is not normal
# Shaheen Shah Afridi
# ShapiroResult(statistic=0.8817436695098877, pvalue=3.6417877047334457e-10)
# Data is not normal
# Bilal Asif
# ShapiroResult(statistic=0.8767508864402771, pvalue=0.0002651950344443321)
# Data is not normal
# Haris Sohail
# ShapiroResult(statistic=0.9200419783592224, pvalue=0.0021093254908919334)
# Data is not normal
# SNJ O'Keefe
# ShapiroResult(statistic=0.9007521271705627, pvalue=5.622812864203297e-07)
# Data is not normal
# AC Agar
# ShapiroResult(statistic=0.9187746644020081, pvalue=0.0011988398618996143)
# Data is not normal
# BE Hendricks
# ShapiroResult(statistic=0.8363760709762573, pvalue=0.0015558775048702955)
# Data is not normal
# A Nortje
# ShapiroResult(statistic=0.9375841021537781, pvalue=3.036991984117776e-06)
# Data is not normal
# D Paterson
# ShapiroResult(statistic=0.8829995393753052, pvalue=0.00034020605380646884)
# Data is not normal
# D Pretorius
# ShapiroResult(statistic=0.8061434626579285, pvalue=0.0006253131432458758)
# Data is not normal
# WPUJC Vaas
# ShapiroResult(statistic=0.9016894102096558, pvalue=1.1538147104417362e-09)
# Data is not normal
# SL Malinga
# ShapiroResult(statistic=0.9129651188850403, pvalue=3.9856073996702435e-09)
# Data is not normal
# CRD Fernando
# ShapiroResult(statistic=0.928704559803009, pvalue=6.204448510516158e-08)
# Data is not normal
# M Muralitharan
# ShapiroResult(statistic=0.9122076630592346, pvalue=8.77976979876521e-17)
# Data is not normal
# MT Chinouya
# ShapiroResult(statistic=0.9022886157035828, pvalue=0.03303883224725723)
# Data is not normal
# CJ Chibhabha
# ShapiroResult(statistic=0.960512638092041, pvalue=0.473797082901001)
# Data may be normal
# AG Cremer
# ShapiroResult(statistic=0.9015264511108398, pvalue=4.3284081180372524e-11)
# Data is not normal
# J Nyumbu
# ShapiroResult(statistic=0.9276745319366455, pvalue=0.026780107989907265)
# Data is not normal
# MJ Hoggard
# ShapiroResult(statistic=0.8720349669456482, pvalue=3.141451739041047e-14)
# Data is not normal
# A Flintoff
# ShapiroResult(statistic=0.8818108439445496, pvalue=1.5498850033240918e-12)
# Data is not normal
# LE Plunkett
# ShapiroResult(statistic=0.9045218825340271, pvalue=8.906344191927928e-06)
# Data is not normal
# SI Mahmood
# ShapiroResult(statistic=0.9168211817741394, pvalue=0.0653451681137085)
# Data may be normal
# M Labuschagne
# ShapiroResult(statistic=0.8721916079521179, pvalue=0.0001225272862939164)
# Data is not normal
# PM Pushpakumara
# ShapiroResult(statistic=0.7814361453056335, pvalue=3.391453437529002e-11)
# Data is not normal
# PADLR Sandakan
# ShapiroResult(statistic=0.9447533488273621, pvalue=0.00015943912148941308)
# Data is not normal
# MD Gunathilaka
# ShapiroResult(statistic=0.80769944190979, pvalue=0.024994011968374252)
# Data is not normal
# Mohammad Abbas
# ShapiroResult(statistic=0.8535810112953186, pvalue=1.0071816783499077e-15)
# Data is not normal
# Asad Shafiq
# ShapiroResult(statistic=0.9137507081031799, pvalue=0.02798600122332573)
# Data is not normal
# Aizaz Cheema
# ShapiroResult(statistic=0.875016987323761, pvalue=2.855095715403877e-07)
# Data is not normal
# Abdur Rehman
# ShapiroResult(statistic=0.8496461510658264, pvalue=8.705550073508534e-21)
# Data is not normal
# CJ Anderson
# ShapiroResult(statistic=0.9155632257461548, pvalue=0.0006414290983229876)
# Data is not normal
# N Deonarine
# ShapiroResult(statistic=0.8105418086051941, pvalue=3.4500579476626214e-11)
# Data is not normal
# PT Collins
# ShapiroResult(statistic=0.875432014465332, pvalue=0.00012948478979524225)
# Data is not normal
# RR Sarwan
# ShapiroResult(statistic=0.9538151025772095, pvalue=0.14838676154613495)
# Data may be normal
# SJ Harmison
# ShapiroResult(statistic=0.9109606742858887, pvalue=3.323990388492959e-11)
# Data is not normal
# AF Giles
# ShapiroResult(statistic=0.929244875907898, pvalue=6.369248148985207e-05)
# Data is not normal
# IR Bell
# ShapiroResult(statistic=0.9090093374252319, pvalue=0.3471405506134033)
# Data may be normal
# Kuldeep Yadav
# ShapiroResult(statistic=0.9300631880760193, pvalue=0.004512081388384104)
# Data is not normal
# SR Harmer
# ShapiroResult(statistic=0.9359297752380371, pvalue=0.0002499780966900289)
# Data is not normal
# S van Zyl
# ShapiroResult(statistic=0.8255953788757324, pvalue=0.0012948239454999566)
# Data is not normal
# G Onions
# ShapiroResult(statistic=0.9203050136566162, pvalue=2.974592234750162e-06)
# Data is not normal
# R Rampaul
# ShapiroResult(statistic=0.8402167558670044, pvalue=4.7919906432693227e-14)
# Data is not normal
# RP Singh
# ShapiroResult(statistic=0.9377569556236267, pvalue=8.916377396417374e-07)
# Data is not normal
# S Sreesanth
# ShapiroResult(statistic=0.9011959433555603, pvalue=4.0281647917424224e-13)
# Data is not normal
# SK Raina
# ShapiroResult(statistic=0.905225396156311, pvalue=0.00020503975974861532)
# Data is not normal
# A Mishra
# ShapiroResult(statistic=0.9028156995773315, pvalue=1.0797959748565233e-11)
# Data is not normal
# JM Bird
# ShapiroResult(statistic=0.8885952234268188, pvalue=2.6856531221142177e-08)
# Data is not normal
# T Panyangara
# ShapiroResult(statistic=0.8629099130630493, pvalue=2.025068624789128e-06)
# Data is not normal
# E Chigumbura
# ShapiroResult(statistic=0.884502112865448, pvalue=2.860163658624515e-05)
# Data is not normal
# N M'shangwe
# ShapiroResult(statistic=0.9033364057540894, pvalue=7.878022188378964e-06)
# Data is not normal
# Taskin Ahmed
# ShapiroResult(statistic=0.9345483183860779, pvalue=0.001018017646856606)
# Data is not normal
# Kamrul Islam Rabbi
# ShapiroResult(statistic=0.9277563095092773, pvalue=0.0191056989133358)
# Data is not normal
# Sabbir Rahman
# ShapiroResult(statistic=0.8257228136062622, pvalue=0.01865006610751152)
# Data is not normal
# Tanvir Ahmed (1)
# ShapiroResult(statistic=0.8850155472755432, pvalue=9.174901606456842e-06)
# Data is not normal
# L Sipamla
# ShapiroResult(statistic=0.8929914832115173, pvalue=0.01533333770930767)
# Data is not normal
# PWA Mulder
# ShapiroResult(statistic=0.8710979223251343, pvalue=0.0031035023275762796)
# Data is not normal
# Mohammad Irfan
# ShapiroResult(statistic=0.8956910967826843, pvalue=0.0014358274638652802)
# Data is not normal
# Zulfiqar Babar
# ShapiroResult(statistic=0.8854632377624512, pvalue=1.4096646516748024e-08)
# Data is not normal
# KA Jamieson
# ShapiroResult(statistic=0.8782037496566772, pvalue=8.49932839628309e-05)
# Data is not normal
# WB Rankin
# ShapiroResult(statistic=0.8232022523880005, pvalue=0.000114840229798574)
# Data is not normal
# FDM Karunaratne
# ShapiroResult(statistic=0.9171255230903625, pvalue=0.03851922228932381)
# Data is not normal
# UWMBCA Welegedara
# ShapiroResult(statistic=0.9175727963447571, pvalue=4.3733880517038415e-08)
# Data is not normal
# J Yadav
# ShapiroResult(statistic=0.929817259311676, pvalue=0.003979352302849293)
# Data is not normal
# Mustafizur Rahman
# ShapiroResult(statistic=0.9088218212127686, pvalue=3.3277169109169336e-07)
# Data is not normal
# Subashis Roy
# ShapiroResult(statistic=0.8783745169639587, pvalue=5.997705557092559e-06)
# Data is not normal
# KD Mills
# ShapiroResult(statistic=0.8908616304397583, pvalue=1.1325202109446764e-07)
# Data is not normal
# JDP Oram
# ShapiroResult(statistic=0.8480862379074097, pvalue=1.977643049322353e-10)
# Data is not normal
# Yuvraj Singh
# ShapiroResult(statistic=0.816709578037262, pvalue=4.657677436625818e-06)
# Data is not normal
# JC Tredwell
# ShapiroResult(statistic=0.8919093608856201, pvalue=0.00455474155023694)
# Data is not normal
# Ehsan Adil
# ShapiroResult(statistic=0.8760469555854797, pvalue=4.0330014599021524e-05)
# Data is not normal
# Usman Shinwari
# ShapiroResult(statistic=0.8965185284614563, pvalue=0.08421912789344788)
# Data may be normal
# Naseem Shah
# ShapiroResult(statistic=0.9438036680221558, pvalue=0.0004827917437069118)
# Data is not normal
# Mahbubul Alam
# ShapiroResult(statistic=0.8837759494781494, pvalue=0.0024535951670259237)
# Data is not normal
# Mehrab Hossain jnr
# ShapiroResult(statistic=0.8579561710357666, pvalue=0.011334204114973545)
# Data is not normal
# TS Roland-Jones
# ShapiroResult(statistic=0.873555600643158, pvalue=0.08610698580741882)
# Data may be normal
# SD Udal
# ShapiroResult(statistic=0.8442058563232422, pvalue=0.0004700439458247274)
# Data is not normal
# Nasir Hossain
# ShapiroResult(statistic=0.7984915375709534, pvalue=1.2016968184980215e-06)
# Data is not normal
# Suhrawadi Shuvo
# ShapiroResult(statistic=0.9004345536231995, pvalue=0.02580670826137066)
# Data is not normal
# Naeem Islam
# ShapiroResult(statistic=0.921265721321106, pvalue=0.032832179218530655)
# Data is not normal
# JEC Franklin
# ShapiroResult(statistic=0.9067605137825012, pvalue=4.035093752463581e-07)
# Data is not normal
# NJ Astle
# ShapiroResult(statistic=0.8958101868629456, pvalue=0.0008110178750939667)
# Data is not normal
# MM Patel
# ShapiroResult(statistic=0.8038748502731323, pvalue=9.349048228288193e-13)
# Data is not normal
# KMA Paul
# ShapiroResult(statistic=0.8756961226463318, pvalue=0.0007882414502091706)
# Data is not normal
# SH Lewis
# ShapiroResult(statistic=0.9370059967041016, pvalue=0.027438394725322723)
# Data is not normal
# SW Masakadza
# ShapiroResult(statistic=0.899176836013794, pvalue=5.1544179768825416e-06)
# Data is not normal
# Sohail Khan
# ShapiroResult(statistic=0.922882616519928, pvalue=6.998376193223521e-06)
# Data is not normal
# Imran Khan (2)
# ShapiroResult(statistic=0.9201531410217285, pvalue=0.0005616818089038134)
# Data is not normal
# Fawad Alam
# ShapiroResult(statistic=0.9040597081184387, pvalue=0.17894406616687775)
# Data may be normal
# R McLaren
# ShapiroResult(statistic=0.9167811870574951, pvalue=0.022147715091705322)
# Data is not normal
# RJ Peterson
# ShapiroResult(statistic=0.8628802299499512, pvalue=7.467684099538019e-06)
# Data is not normal
# J Lewis
# ShapiroResult(statistic=0.9150164127349854, pvalue=0.06902988255023956)
# Data may be normal
# A Mithun
# ShapiroResult(statistic=0.9351385235786438, pvalue=0.0009938246803358197)
# Data is not normal
# BP Martin
# ShapiroResult(statistic=0.8499267101287842, pvalue=6.243938344141498e-08)
# Data is not normal
# Yamin Ahmadzai
# ShapiroResult(statistic=0.8022939562797546, pvalue=7.220438419608399e-05)
# Data is not normal
# Wafadar Momand
# ShapiroResult(statistic=0.8273769021034241, pvalue=0.0002695744333323091)
# Data is not normal
# Mohammad Nabi
# ShapiroResult(statistic=0.8841195702552795, pvalue=0.005903105717152357)
# Data is not normal
# Rashid Khan
# ShapiroResult(statistic=0.8243457078933716, pvalue=7.0538162617594935e-06)
# Data is not normal
# Waqar Salamkheil
# ShapiroResult(statistic=0.8423147201538086, pvalue=0.017495188862085342)
# Data is not normal
# WRS de Silva
# ShapiroResult(statistic=0.9022393822669983, pvalue=0.16953130066394806)
# Data may be normal
# MF Maharoof
# ShapiroResult(statistic=0.8944900035858154, pvalue=7.379548083719101e-10)
# Data is not normal
# Bilawal Bhatti
# ShapiroResult(statistic=0.8981287479400635, pvalue=0.089115209877491)
# Data may be normal
# DR Tuffey
# ShapiroResult(statistic=0.8429197669029236, pvalue=1.8950652247440303e-06)
# Data is not normal
# Mohammad Shahid
# ShapiroResult(statistic=0.8493087291717529, pvalue=6.37333073427726e-07)
# Data is not normal
# Shuvagata Hom
# ShapiroResult(statistic=0.8828185796737671, pvalue=1.4636161722592078e-05)
# Data is not normal
# Jubair Hossain
# ShapiroResult(statistic=0.9661116600036621, pvalue=0.17791250348091125)
# Data may be normal
# LH Ferguson
# ShapiroResult(statistic=0.9373289942741394, pvalue=0.4896247982978821)
# Data may be normal
# JA Raval
# ShapiroResult(statistic=0.8838949799537659, pvalue=0.08053775876760483)
# Data may be normal
# DM Washington
# ShapiroResult(statistic=0.9375070929527283, pvalue=0.17577554285526276)
# Data may be normal
# IJL Trott
# ShapiroResult(statistic=0.9085873961448669, pvalue=0.0008242515032179654)
# Data is not normal
# CK Langeveldt
# ShapiroResult(statistic=0.8065484762191772, pvalue=0.011472463607788086)
# Data is not normal
# Syed Rasel
# ShapiroResult(statistic=0.9545155167579651, pvalue=0.0754147469997406)
# Data may be normal
# Al-Amin Hossain
# ShapiroResult(statistic=0.8773052096366882, pvalue=7.225614240269351e-07)
# Data is not normal
# DR Smith
# ShapiroResult(statistic=0.9437272548675537, pvalue=0.33518511056900024)
# Data may be normal
# D Olivier
# ShapiroResult(statistic=0.8658246397972107, pvalue=5.0096685299649835e-05)
# Data is not normal
# KMDN Kulasekara
# ShapiroResult(statistic=0.923804759979248, pvalue=6.217497627858393e-09)
# Data is not normal
# CJ Jordan
# ShapiroResult(statistic=0.8952237367630005, pvalue=5.311668792273849e-05)
# Data is not normal
# JJ Krejza
# ShapiroResult(statistic=0.9274964332580566, pvalue=0.009551816619932652)
# Data is not normal
# TJ Murtagh
# ShapiroResult(statistic=0.8573993444442749, pvalue=0.00041145842988044024)
# Data is not normal
# SR Thompson
# ShapiroResult(statistic=0.8098276257514954, pvalue=0.0003330957260914147)
# Data is not normal
# GC Tonge
# ShapiroResult(statistic=0.8918414115905762, pvalue=0.04150642454624176)
# Data is not normal
# RS Bopara
# ShapiroResult(statistic=0.9632782340049744, pvalue=0.8118097186088562)
# Data may be normal
# SCG MacGill
# ShapiroResult(statistic=0.8121733069419861, pvalue=3.154942618266432e-08)
# Data is not normal
# MVT Fernando
# ShapiroResult(statistic=0.9189496636390686, pvalue=2.486362745912629e-06)
# Data is not normal
# TK Curran
# ShapiroResult(statistic=0.9118449091911316, pvalue=0.05972001329064369)
# Data may be normal
# Sohag Gazi
# ShapiroResult(statistic=0.8667315244674683, pvalue=3.2711561324255678e-12)
# Data is not normal
# HMCM Bandara
# ShapiroResult(statistic=0.8323944807052612, pvalue=5.335852620191872e-06)
# Data is not normal
# L Embuldeniya
# ShapiroResult(statistic=0.9400219321250916, pvalue=9.742645488586277e-06)
# Data is not normal
# NLTC Perera
# ShapiroResult(statistic=0.9351203441619873, pvalue=0.02631217986345291)
# Data is not normal
# AJ Hall
# ShapiroResult(statistic=0.6623657941818237, pvalue=4.466181417228654e-05)
# Data is not normal
# Ebadat Hossain
# ShapiroResult(statistic=0.7671034336090088, pvalue=0.0007431700360029936)
# Data is not normal
# Abu Jayed
# ShapiroResult(statistic=0.8479715585708618, pvalue=1.9415981569181895e-06)
# Data is not normal
# MD Shanaka
# ShapiroResult(statistic=0.8693641424179077, pvalue=0.004200928378850222)
# Data is not normal
# Shahid Afridi
# ShapiroResult(statistic=0.8592882752418518, pvalue=0.00497748889029026)
# Data is not normal
# Imran Farhat
# ShapiroResult(statistic=0.941260576248169, pvalue=0.3334386348724365)
# Data may be normal
# Iftikhar Anjum
# ShapiroResult(statistic=0.9492665529251099, pvalue=0.6345947980880737)
# Data may be normal
# DM Bess
# ShapiroResult(statistic=0.8215453624725342, pvalue=0.0018439439591020346)
# Data is not normal
# CR Brathwaite
# ShapiroResult(statistic=0.9406859874725342, pvalue=0.009094641543924809)
# Data is not normal
# WER Somerville
# ShapiroResult(statistic=0.9348164796829224, pvalue=0.038982734084129333)
# Data is not normal
# CT Mumba
# ShapiroResult(statistic=0.8102458715438843, pvalue=2.71409226115793e-06)
# Data is not normal
# SE Bond
# ShapiroResult(statistic=0.9318881034851074, pvalue=0.0019657874945551157)
# Data is not normal
# LL Tsotsobe
# ShapiroResult(statistic=0.9027683734893799, pvalue=0.04648742079734802)
# Data is not normal
# VRV Singh
# ShapiroResult(statistic=0.9211344122886658, pvalue=0.25984370708465576)
# Data may be normal
# GC Smith
# ShapiroResult(statistic=0.9427503943443298, pvalue=0.08962619304656982)
# Data may be normal
# Iftikhar Ahmed
# ShapiroResult(statistic=0.923968493938446, pvalue=0.19535578787326813)
# Data may be normal
# TD Astle
# ShapiroResult(statistic=0.9414968490600586, pvalue=0.05147567391395569)
# Data may be normal
# RK Kleinveldt
# ShapiroResult(statistic=0.8671789169311523, pvalue=0.008520546369254589)
# Data is not normal
# PP Chawla
# ShapiroResult(statistic=0.9477782249450684, pvalue=0.03853047266602516)
# Data is not normal
# JL Gunn
# ShapiroResult(statistic=0.8162192106246948, pvalue=0.0003366410674061626)
# Data is not normal
# D Hazell
# ShapiroResult(statistic=0.8411216139793396, pvalue=0.007874812930822372)
# Data is not normal
# P Kumar
# ShapiroResult(statistic=0.8567286133766174, pvalue=3.1398684541272814e-07)
# Data is not normal
# Shadab Khan
# ShapiroResult(statistic=0.9070635437965393, pvalue=0.0035392253194004297)
# Data is not normal
# ST Jayasuriya
# ShapiroResult(statistic=0.9683970808982849, pvalue=0.7897798418998718)
# Data may be normal
# Yasir Arafat
# ShapiroResult(statistic=0.9387626051902771, pvalue=0.0005444840644486248)
# Data is not normal
# P Utseya
# ShapiroResult(statistic=0.8550773859024048, pvalue=0.0033674745354801416)
# Data is not normal
# CH Morris
# ShapiroResult(statistic=0.8951541185379028, pvalue=0.0006717568612657487)
# Data is not normal
# C Green
# ShapiroResult(statistic=0.885975182056427, pvalue=0.18130752444267273)
# Data may be normal
# T Shamsi
# ShapiroResult(statistic=0.8791058659553528, pvalue=0.006623599678277969)
# Data is not normal
# RA Reifer
# ShapiroResult(statistic=0.8058642148971558, pvalue=0.0024439485277980566)
# Data is not normal
# KK Peters
# ShapiroResult(statistic=0.8417179584503174, pvalue=0.0038845494855195284)
# Data is not normal
# Mohammad Sharif
# ShapiroResult(statistic=0.935092568397522, pvalue=0.11397985368967056)
# Data may be normal
# DE Bernard
# ShapiroResult(statistic=0.9054675102233887, pvalue=0.21532714366912842)
# Data may be normal
# RA Austin
# ShapiroResult(statistic=0.8143951892852783, pvalue=0.010157749988138676)
# Data is not normal
# Muhammad Musa
# ShapiroResult(statistic=0.9546769261360168, pvalue=0.44367700815200806)
# Data may be normal
# Nazmul Islam
# ShapiroResult(statistic=0.796561598777771, pvalue=0.00033773205359466374)
# Data is not normal
# J Botha
# ShapiroResult(statistic=0.889816164970398, pvalue=0.004052575211971998)
# Data is not normal
# S Muthusamy
# ShapiroResult(statistic=0.8932188153266907, pvalue=0.0030513443052768707)
# Data is not normal
# J Goswami
# ShapiroResult(statistic=0.7782495617866516, pvalue=0.0048699830658733845)
# Data is not normal
# N Niranjana
# ShapiroResult(statistic=0.8208704590797424, pvalue=0.009149868972599506)
# Data is not normal
# BJ Arnel
# ShapiroResult(statistic=0.8451208472251892, pvalue=0.00010017093154601753)
# Data is not normal
# BV Vitori
# ShapiroResult(statistic=0.9218535423278809, pvalue=0.05647306144237518)
# Data may be normal
# JA Morkel
# ShapiroResult(statistic=0.8923288583755493, pvalue=0.1262785643339157)
# Data may be normal
# Abul Hasan
# ShapiroResult(statistic=0.9538569450378418, pvalue=0.265532910823822)
# Data may be normal
# Elias Sunny
# ShapiroResult(statistic=0.9445245862007141, pvalue=0.31756791472435)
# Data may be normal
# B Muzarabani
# ShapiroResult(statistic=0.8429136872291565, pvalue=0.023094424977898598)
# Data is not normal
# MS Dhoni
# ShapiroResult(statistic=0.9572120308876038, pvalue=0.7831634879112244)
# Data may be normal
# C Munro
# ShapiroResult(statistic=0.8695855736732483, pvalue=0.017515359446406364)
# Data is not normal
# SC Kerrigan
# ShapiroResult(statistic=0.840064287185669, pvalue=0.07543689757585526)
# Data may be normal
# JT Ball
# ShapiroResult(statistic=0.8459670543670654, pvalue=0.005771794356405735)
# Data is not normal
# MR Gillespie
# ShapiroResult(statistic=0.8960371017456055, pvalue=0.0002715392620302737)
# Data is not normal
# M Zondeki
# ShapiroResult(statistic=0.8797138929367065, pvalue=0.00017252260295208544)
# Data is not normal
# MJ Leach
# ShapiroResult(statistic=0.9261917471885681, pvalue=0.055774055421352386)
# Data may be normal
# HH Streak
# ShapiroResult(statistic=0.8918301463127136, pvalue=0.017219576984643936)
# Data is not normal
# NB Mahwire
# ShapiroResult(statistic=0.9288826584815979, pvalue=0.0728900358080864)
# Data may be normal
# SP Jones
# ShapiroResult(statistic=0.9542214274406433, pvalue=0.2905256748199463)
# Data may be normal
# Mohammad Talha
# ShapiroResult(statistic=0.9234535694122314, pvalue=0.004415565170347691)
# Data is not normal
# Mohammed Siraj
# ShapiroResult(statistic=0.8206583261489868, pvalue=1.8810700566973537e-05)
# Data is not normal
# GF Linde
# ShapiroResult(statistic=0.799192488193512, pvalue=4.987138891010545e-05)
# Data is not normal
# GB Hogg
# ShapiroResult(statistic=0.802670955657959, pvalue=5.7861991081153974e-05)
# Data is not normal
# Faheem Ashraf
# ShapiroResult(statistic=0.8945868015289307, pvalue=0.000860674655996263)
# Data is not normal
# JW Hastings
# ShapiroResult(statistic=0.7639018297195435, pvalue=0.00026235845871269703)
# Data is not normal
# NA Saini
# ShapiroResult(statistic=0.8774868249893188, pvalue=0.06594301760196686)
# Data may be normal
# TE Kane
# ShapiroResult(statistic=0.8894422054290771, pvalue=0.02626507170498371)
# Data is not normal
# NT Pascal
# ShapiroResult(statistic=0.918242871761322, pvalue=0.3042761981487274)
# Data may be normal
# KO Meth
# ShapiroResult(statistic=0.8065179586410522, pvalue=0.0006339366664178669)
# Data is not normal
# SW Tait
# ShapiroResult(statistic=0.8981978893280029, pvalue=0.1263270378112793)
# Data may be normal
# CJ Sayers
# ShapiroResult(statistic=0.9196803569793701, pvalue=0.0139571912586689)
# Data is not normal
# SS Cottrell
# ShapiroResult(statistic=0.9689733386039734, pvalue=0.5533429980278015)
# Data may be normal
# Mujeeb Ur Rahman
# ShapiroResult(statistic=0.8530329465866089, pvalue=0.019176006317138672)
# Data is not normal
# JA Richardson
# ShapiroResult(statistic=0.8797016143798828, pvalue=0.0575493685901165)
# Data may be normal
# C Karunaratne
# ShapiroResult(statistic=0.9600459337234497, pvalue=0.4902076721191406)
# Data may be normal
# KL Cross
# ShapiroResult(statistic=0.9520730376243591, pvalue=0.5232256650924683)
# Data may be normal
# HC Knight
# ShapiroResult(statistic=0.7243107557296753, pvalue=0.0009633323061279953)
# Data is not normal
# 360 64

# %%
#Anderson-Darling Test
from scipy.stats import anderson

notnormcount = 0
maybenormcount = 0

for name in bdfdict:
    
    if(len(bdfdict[name]['runs'])>=8):
        
        print(name)
        
        data = bdfdict[name]['runs']
        result = anderson(data)
        
        print('Statistic: %.3f' % result.statistic)
        p = 0
        notnormflag = False
        
        for i in range(len(result.critical_values)):
            
            sl, cv = result.significance_level[i], result.critical_values[i]
            
            if result.statistic < result.critical_values[i]:
                print('%.3f: %.3f, data may be normal' % (sl, cv))
                notnormflag = False
                
            else:
                print('%.3f: %.3f, data is not normal' % (sl, cv))
                notnormflag = True
                break
            
        if notnormflag:
            notnormcount += 1
        else:
            maybenormcount += 1
        
print(notnormcount, maybenormcount)
# Out:
# B Lee
# Statistic: 7.213
# 15.000: 0.569, data is not normal
# PM Siddle
# Statistic: 20.417
# 15.000: 0.572, data is not normal
# MG Johnson
# Statistic: 13.572
# 15.000: 0.572, data is not normal
# SR Watson
# Statistic: 5.827
# 15.000: 0.565, data is not normal
# MJ Clarke
# Statistic: 1.574
# 15.000: 0.553, data is not normal
# CL White
# Statistic: 1.336
# 15.000: 0.534, data is not normal
# JM Anderson
# Statistic: 50.637
# 15.000: 0.574, data is not normal
# SCJ Broad
# Statistic: 37.954
# 15.000: 0.574, data is not normal
# MS Panesar
# Statistic: 19.379
# 15.000: 0.571, data is not normal
# GP Swann
# Statistic: 23.695
# 15.000: 0.573, data is not normal
# SR Patel
# Statistic: 3.488
# 15.000: 0.551, data is not normal
# KM Jarvis
# Statistic: 3.955
# 15.000: 0.561, data is not normal
# TL Chatara
# Statistic: 3.056
# 15.000: 0.548, data is not normal
# DT Tiripano
# Statistic: 2.267
# 15.000: 0.556, data is not normal
# Sikandar Raza
# Statistic: 1.866
# 15.000: 0.553, data is not normal
# SC Williams
# Statistic: 3.702
# 15.000: 0.551, data is not normal
# B Mavuta
# Statistic: 0.734
# 15.000: 0.522, data is not normal
# H Masakadza
# Statistic: 3.603
# 15.000: 0.548, data is not normal
# BW Hilfenhaus
# Statistic: 7.684
# 15.000: 0.566, data is not normal
# XJ Doherty
# Statistic: 1.013
# 15.000: 0.497, data is not normal
# MJ North
# Statistic: 0.752
# 15.000: 0.523, data is not normal
# CT Tremlett
# Statistic: 5.733
# 15.000: 0.563, data is not normal
# TT Bresnan
# Statistic: 8.168
# 15.000: 0.568, data is not normal
# MA Starc
# Statistic: 12.996
# 15.000: 0.572, data is not normal
# NM Lyon
# Statistic: 33.851
# 15.000: 0.574, data is not normal
# MR Marsh
# Statistic: 5.012
# 15.000: 0.564, data is not normal
# GJ Maxwell
# Statistic: 0.625
# 15.000: 0.514, data is not normal
# SPD Smith
# Statistic: 1.962
# 15.000: 0.535, data is not normal
# MA Wood
# Statistic: 4.272
# 15.000: 0.559, data is not normal
# BA Stokes
# Statistic: 11.529
# 15.000: 0.571, data is not normal
# ST Finn
# Statistic: 6.986
# 15.000: 0.569, data is not normal
# MM Ali
# Statistic: 6.139
# 15.000: 0.570, data is not normal
# JE Root
# Statistic: 0.961
# 15.000: 0.544, data is not normal
# DW Steyn
# Statistic: 27.181
# 15.000: 0.573, data is not normal
# M Morkel
# Statistic: 23.866
# 15.000: 0.573, data is not normal
# M de Lange
# Statistic: 1.043
# 15.000: 0.511, data is not normal
# Imran Tahir
# Statistic: 4.528
# 15.000: 0.564, data is not normal
# JH Kallis
# Statistic: 12.603
# 15.000: 0.571, data is not normal
# Taijul Islam
# Statistic: 14.498
# 15.000: 0.571, data is not normal
# Shakib Al Hasan
# Statistic: 24.727
# 15.000: 0.573, data is not normal
# Mehedi Hasan Miraz
# Statistic: 9.763
# 15.000: 0.568, data is not normal
# Nayeem Hasan
# Statistic: 2.324
# 15.000: 0.539, data is not normal
# Mahmudullah
# Statistic: 7.620
# 15.000: 0.566, data is not normal
# Soumya Sarkar
# Statistic: 0.799
# 15.000: 0.526, data is not normal
# Mominul Haque
# Statistic: 1.605
# 15.000: 0.513, data is not normal
# B Kumar
# Statistic: 5.470
# 15.000: 0.565, data is not normal
# Mohammed Shami
# Statistic: 7.857
# 15.000: 0.570, data is not normal
# R Ashwin
# Statistic: 33.293
# 15.000: 0.574, data is not normal
# PP Ojha
# Statistic: 18.341
# 15.000: 0.572, data is not normal
# SR Tendulkar
# Statistic: 0.621
# 15.000: 0.513, data is not normal
# Z Khan
# Statistic: 15.728
# 15.000: 0.573, data is not normal
# I Sharma
# Statistic: 33.583
# 15.000: 0.574, data is not normal
# Harbhajan Singh
# Statistic: 30.691
# 15.000: 0.574, data is not normal
# V Sehwag
# Statistic: 3.927
# 15.000: 0.563, data is not normal
# RAS Lakmal
# Statistic: 18.416
# 15.000: 0.572, data is not normal
# RMS Eranga
# Statistic: 7.395
# 15.000: 0.568, data is not normal
# AD Mathews
# Statistic: 10.270
# 15.000: 0.569, data is not normal
# KTGD Prasad
# Statistic: 2.603
# 15.000: 0.566, data is not normal
# PHT Kaushal
# Statistic: 1.913
# 15.000: 0.549, data is not normal
# JL Pattinson
# Statistic: 2.597
# 15.000: 0.561, data is not normal
# MEK Hussey
# Statistic: 0.522
# 15.000: 0.503, data is not normal
# Shafiul Islam
# Statistic: 3.086
# 15.000: 0.561, data is not normal
# Robiul Islam
# Statistic: 4.001
# 15.000: 0.559, data is not normal
# Rubel Hossain
# Statistic: 4.692
# 15.000: 0.567, data is not normal
# Abdur Razzak
# Statistic: 6.369
# 15.000: 0.566, data is not normal
# FH Edwards
# Statistic: 8.439
# 15.000: 0.570, data is not normal
# TL Best
# Statistic: 2.585
# 15.000: 0.561, data is not normal
# DJG Sammy
# Statistic: 12.398
# 15.000: 0.570, data is not normal
# SP Narine
# Statistic: 2.820
# 15.000: 0.553, data is not normal
# V Permaul
# Statistic: 2.219
# 15.000: 0.549, data is not normal
# MN Samuels
# Statistic: 3.983
# 15.000: 0.564, data is not normal
# JC Archer
# Statistic: 4.127
# 15.000: 0.557, data is not normal
# CR Woakes
# Statistic: 9.296
# 15.000: 0.568, data is not normal
# SM Curran
# Statistic: 2.847
# 15.000: 0.552, data is not normal
# JL Denly
# Statistic: 0.492
# 15.000: 0.498, data may be normal
# 10.000: 0.567, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.944, data may be normal
# JJ Bumrah
# Statistic: 6.322
# 15.000: 0.562, data is not normal
# GH Vihari
# Statistic: 0.543
# 15.000: 0.498, data is not normal
# RA Jadeja
# Statistic: 21.372
# 15.000: 0.572, data is not normal
# Mohammad Sami
# Statistic: 2.853
# 15.000: 0.563, data is not normal
# Umar Gul
# Statistic: 18.170
# 15.000: 0.572, data is not normal
# Shahid Nazir
# Statistic: 1.647
# 15.000: 0.540, data is not normal
# Danish Kaneria
# Statistic: 11.488
# 15.000: 0.571, data is not normal
# Salman Butt
# Statistic: 0.494
# 15.000: 0.508, data may be normal
# 10.000: 0.579, data may be normal
# 5.000: 0.694, data may be normal
# 2.500: 0.810, data may be normal
# 1.000: 0.963, data may be normal
# TA Boult
# Statistic: 25.454
# 15.000: 0.573, data is not normal
# TG Southee
# Statistic: 25.841
# 15.000: 0.573, data is not normal
# C de Grandhomme
# Statistic: 10.971
# 15.000: 0.568, data is not normal
# N Wagner
# Statistic: 23.698
# 15.000: 0.573, data is not normal
# AY Patel
# Statistic: 1.466
# 15.000: 0.544, data is not normal
# Mohammad Asif
# Statistic: 9.324
# 15.000: 0.569, data is not normal
# KAJ Roach
# Statistic: 22.222
# 15.000: 0.573, data is not normal
# JO Holder
# Statistic: 23.813
# 15.000: 0.572, data is not normal
# RRS Cornwall
# Statistic: 4.357
# 15.000: 0.554, data is not normal
# JA Warrican
# Statistic: 4.077
# 15.000: 0.561, data is not normal
# RL Chase
# Statistic: 10.545
# 15.000: 0.571, data is not normal
# T Thushara
# Statistic: 1.367
# 15.000: 0.538, data is not normal
# BAW Mendis
# Statistic: 5.596
# 15.000: 0.564, data is not normal
# S Randiv
# Statistic: 6.587
# 15.000: 0.562, data is not normal
# TM Dilshan
# Statistic: 3.388
# 15.000: 0.552, data is not normal
# N Pradeep
# Statistic: 6.109
# 15.000: 0.569, data is not normal
# PVD Chameera
# Statistic: 1.643
# 15.000: 0.553, data is not normal
# HMRKB Herath
# Statistic: 29.073
# 15.000: 0.574, data is not normal
# TAM Siriwardana
# Statistic: 0.391
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.679, data may be normal
# 2.500: 0.792, data may be normal
# 1.000: 0.942, data may be normal
# JS Patel
# Statistic: 10.488
# 15.000: 0.568, data is not normal
# MJ Santner
# Statistic: 5.507
# 15.000: 0.567, data is not normal
# JDS Neesham
# Statistic: 1.466
# 15.000: 0.540, data is not normal
# KJ Abbott
# Statistic: 4.192
# 15.000: 0.553, data is not normal
# DL Piedt
# Statistic: 4.285
# 15.000: 0.561, data is not normal
# D Elgar
# Statistic: 1.075
# 15.000: 0.550, data is not normal
# JP Duminy
# Statistic: 4.386
# 15.000: 0.559, data is not normal
# UT Yadav
# Statistic: 6.992
# 15.000: 0.570, data is not normal
# M Vijay
# Statistic: 1.103
# 15.000: 0.510, data is not normal
# ST Gabriel
# Statistic: 13.551
# 15.000: 0.572, data is not normal
# AS Joseph
# Statistic: 5.362
# 15.000: 0.565, data is not normal
# CK Holder
# Statistic: 0.838
# 15.000: 0.516, data is not normal
# ZS Ansari
# Statistic: 0.892
# 15.000: 0.503, data is not normal
# AU Rashid
# Statistic: 4.063
# 15.000: 0.560, data is not normal
# DBL Powell
# Statistic: 6.805
# 15.000: 0.569, data is not normal
# LS Baker
# Statistic: 2.536
# 15.000: 0.550, data is not normal
# BP Nash
# Statistic: 1.720
# 15.000: 0.538, data is not normal
# CH Gayle
# Statistic: 7.508
# 15.000: 0.567, data is not normal
# RO Hinds
# Statistic: 2.070
# 15.000: 0.550, data is not normal
# LMP Simmons
# Statistic: 0.921
# 15.000: 0.516, data is not normal
# Junaid Khan
# Statistic: 8.365
# 15.000: 0.568, data is not normal
# Rahat Ali
# Statistic: 4.947
# 15.000: 0.565, data is not normal
# Saeed Ajmal
# Statistic: 21.227
# 15.000: 0.573, data is not normal
# Younis Khan
# Statistic: 0.613
# 15.000: 0.534, data is not normal
# Mohammad Hafeez
# Statistic: 4.554
# 15.000: 0.562, data is not normal
# SR Clark
# Statistic: 8.651
# 15.000: 0.568, data is not normal
# MS Kasprowicz
# Statistic: 1.653
# 15.000: 0.544, data is not normal
# SK Warne
# Statistic: 5.839
# 15.000: 0.566, data is not normal
# A Symonds
# Statistic: 3.274
# 15.000: 0.554, data is not normal
# Shahadat Hossain
# Statistic: 4.584
# 15.000: 0.569, data is not normal
# Enamul Haque jnr
# Statistic: 3.235
# 15.000: 0.559, data is not normal
# Mohammad Ashraful
# Statistic: 0.560
# 15.000: 0.523, data is not normal
# MJ Henry
# Statistic: 5.100
# 15.000: 0.565, data is not normal
# DAJ Bracewell
# Statistic: 6.099
# 15.000: 0.567, data is not normal
# MD Craig
# Statistic: 3.361
# 15.000: 0.562, data is not normal
# KS Williamson
# Statistic: 1.784
# 15.000: 0.549, data is not normal
# BB McCullum
# Statistic: 0.650
# 15.000: 0.497, data is not normal
# C Overton
# Statistic: 2.098
# 15.000: 0.544, data is not normal
# CBRLS Kumara
# Statistic: 5.843
# 15.000: 0.568, data is not normal
# CAK Rajitha
# Statistic: 2.172
# 15.000: 0.556, data is not normal
# MDK Perera
# Statistic: 10.014
# 15.000: 0.571, data is not normal
# GD McGrath
# Statistic: 7.500
# 15.000: 0.564, data is not normal
# JN Gillespie
# Statistic: 2.132
# 15.000: 0.539, data is not normal
# M Ntini
# Statistic: 11.986
# 15.000: 0.571, data is not normal
# PL Harris
# Statistic: 11.254
# 15.000: 0.568, data is not normal
# CS Martin
# Statistic: 12.872
# 15.000: 0.571, data is not normal
# IE O'Brien
# Statistic: 5.641
# 15.000: 0.565, data is not normal
# GD Elliott
# Statistic: 1.117
# 15.000: 0.506, data is not normal
# DL Vettori
# Statistic: 24.372
# 15.000: 0.572, data is not normal
# JD Ryder
# Statistic: 1.225
# 15.000: 0.523, data is not normal
# KC Brathwaite
# Statistic: 7.204
# 15.000: 0.564, data is not normal
# KH Brunt
# Statistic: 3.579
# 15.000: 0.547, data is not normal
# A Shrubsole
# Statistic: 3.608
# 15.000: 0.549, data is not normal
# S Ecclestone
# Statistic: 1.063
# 15.000: 0.526, data is not normal
# NR Sciver
# Statistic: 0.392
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.943, data may be normal
# KL Gordon
# Statistic: 0.871
# 15.000: 0.517, data is not normal
# LA Marsh
# Statistic: 2.077
# 15.000: 0.551, data is not normal
# JE Taylor
# Statistic: 14.356
# 15.000: 0.572, data is not normal
# J Blackwood
# Statistic: 0.812
# 15.000: 0.498, data is not normal
# Pankaj Singh
# Statistic: 1.460
# 15.000: 0.529, data is not normal
# RG Sharma
# Statistic: 0.629
# 15.000: 0.497, data is not normal
# NM Hauritz
# Statistic: 4.841
# 15.000: 0.551, data is not normal
# SM Katich
# Statistic: 0.980
# 15.000: 0.506, data is not normal
# Shoaib Akhtar
# Statistic: 1.168
# 15.000: 0.535, data is not normal
# Sohail Tanvir
# Statistic: 1.682
# 15.000: 0.530, data is not normal
# Yasir Hameed
# Statistic: 0.404
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.679, data may be normal
# 2.500: 0.792, data may be normal
# 1.000: 0.942, data may be normal
# Mashrafe Mortaza
# Statistic: 3.926
# 15.000: 0.560, data is not normal
# Mohammad Rafique
# Statistic: 3.631
# 15.000: 0.560, data is not normal
# Aftab Ahmed
# Statistic: 1.120
# 15.000: 0.503, data is not normal
# RJ Harris
# Statistic: 6.216
# 15.000: 0.562, data is not normal
# TA Copeland
# Statistic: 1.169
# 15.000: 0.497, data is not normal
# VR Aaron
# Statistic: 1.643
# 15.000: 0.548, data is not normal
# KV Sharma
# Statistic: 1.542
# 15.000: 0.523, data is not normal
# VD Philander
# Statistic: 19.733
# 15.000: 0.572, data is not normal
# A Dananjaya
# Statistic: 1.886
# 15.000: 0.545, data is not normal
# DM de Silva
# Statistic: 2.249
# 15.000: 0.560, data is not normal
# D Bishoo
# Statistic: 8.676
# 15.000: 0.571, data is not normal
# IS Sodhi
# Statistic: 5.398
# 15.000: 0.562, data is not normal
# KA Maharaj
# Statistic: 13.735
# 15.000: 0.570, data is not normal
# K Rabada
# Statistic: 9.495
# 15.000: 0.571, data is not normal
# AK Markram
# Statistic: 1.284
# 15.000: 0.497, data is not normal
# TB de Bruyn
# Statistic: 0.435
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.679, data may be normal
# 2.500: 0.792, data may be normal
# 1.000: 0.942, data may be normal
# DA Warner
# Statistic: 0.368
# 15.000: 0.500, data may be normal
# 10.000: 0.569, data may be normal
# 5.000: 0.683, data may be normal
# 2.500: 0.797, data may be normal
# 1.000: 0.948, data may be normal
# SJ Benn
# Statistic: 19.176
# 15.000: 0.572, data is not normal
# S Shillingford
# Statistic: 15.974
# 15.000: 0.570, data is not normal
# ML Cummins
# Statistic: 2.826
# 15.000: 0.561, data is not normal
# CD Collymore
# Statistic: 6.424
# 15.000: 0.564, data is not normal
# DJ Bravo
# Statistic: 8.162
# 15.000: 0.570, data is not normal
# D Mohammed
# Statistic: 0.536
# 15.000: 0.503, data is not normal
# N Ncube
# Statistic: 0.624
# 15.000: 0.514, data is not normal
# CB Mpofu
# Statistic: 3.157
# 15.000: 0.560, data is not normal
# RW Price
# Statistic: 1.757
# 15.000: 0.533, data is not normal
# MN Waller
# Statistic: 1.899
# 15.000: 0.529, data is not normal
# SM Pollock
# Statistic: 6.544
# 15.000: 0.560, data is not normal
# A Nel
# Statistic: 8.483
# 15.000: 0.566, data is not normal
# N Boje
# Statistic: 3.602
# 15.000: 0.555, data is not normal
# HH Pandya
# Statistic: 1.126
# 15.000: 0.536, data is not normal
# DE Bollinger
# Statistic: 1.875
# 15.000: 0.514, data is not normal
# PLS Gamage
# Statistic: 2.568
# 15.000: 0.547, data is not normal
# IDR Bradshaw
# Statistic: 2.897
# 15.000: 0.549, data is not normal
# RJ Sidebottom
# Statistic: 7.356
# 15.000: 0.565, data is not normal
# PD Collingwood
# Statistic: 2.270
# 15.000: 0.546, data is not normal
# KP Pietersen
# Statistic: 1.134
# 15.000: 0.535, data is not normal
# HK Bennett
# Statistic: 0.793
# 15.000: 0.498, data is not normal
# IK Pathan
# Statistic: 3.437
# 15.000: 0.556, data is not normal
# SC Ganguly
# Statistic: 2.411
# 15.000: 0.542, data is not normal
# A Kumble
# Statistic: 12.694
# 15.000: 0.571, data is not normal
# Mohammad Amir
# Statistic: 13.755
# 15.000: 0.571, data is not normal
# Abdur Rauf
# Statistic: 0.474
# 15.000: 0.528, data may be normal
# 10.000: 0.601, data may be normal
# 5.000: 0.721, data may be normal
# 2.500: 0.841, data may be normal
# 1.000: 1.000, data may be normal
# Shoaib Malik
# Statistic: 1.725
# 15.000: 0.555, data is not normal
# L Ngidi
# Statistic: 2.422
# 15.000: 0.553, data is not normal
# JR Hazlewood
# Statistic: 18.400
# 15.000: 0.572, data is not normal
# PJ Cummins
# Statistic: 10.720
# 15.000: 0.570, data is not normal
# Wahab Riaz
# Statistic: 8.509
# 15.000: 0.569, data is not normal
# Yasir Shah
# Statistic: 18.905
# 15.000: 0.573, data is not normal
# Azhar Ali
# Statistic: 1.494
# 15.000: 0.545, data is not normal
# Shan Masood
# Statistic: 0.675
# 15.000: 0.501, data is not normal
# AS Jaggernauth
# Statistic: 0.605
# 15.000: 0.506, data is not normal
# Abdul Razzaq
# Statistic: 1.437
# 15.000: 0.534, data is not normal
# JM Holland
# Statistic: 2.397
# 15.000: 0.554, data is not normal
# Hasan Ali
# Statistic: 2.367
# 15.000: 0.554, data is not normal
# Shaheen Shah Afridi
# Statistic: 4.477
# 15.000: 0.563, data is not normal
# Bilal Asif
# Statistic: 1.818
# 15.000: 0.534, data is not normal
# Haris Sohail
# Statistic: 1.084
# 15.000: 0.539, data is not normal
# SNJ O'Keefe
# Statistic: 3.462
# 15.000: 0.557, data is not normal
# AC Agar
# Statistic: 1.139
# 15.000: 0.541, data is not normal
# BE Hendricks
# Statistic: 1.128
# 15.000: 0.511, data is not normal
# A Nortje
# Statistic: 2.347
# 15.000: 0.562, data is not normal
# D Paterson
# Statistic: 1.375
# 15.000: 0.534, data is not normal
# D Pretorius
# Statistic: 1.598
# 15.000: 0.510, data is not normal
# WPUJC Vaas
# Statistic: 4.594
# 15.000: 0.564, data is not normal
# SL Malinga
# Statistic: 4.253
# 15.000: 0.564, data is not normal
# CRD Fernando
# Statistic: 3.619
# 15.000: 0.564, data is not normal
# M Muralitharan
# Statistic: 12.619
# 15.000: 0.572, data is not normal
# MT Chinouya
# Statistic: 0.683
# 15.000: 0.510, data is not normal
# CJ Chibhabha
# Statistic: 0.280
# 15.000: 0.511, data may be normal
# 10.000: 0.582, data may be normal
# 5.000: 0.699, data may be normal
# 2.500: 0.815, data may be normal
# 1.000: 0.969, data may be normal
# AG Cremer
# Statistic: 5.544
# 15.000: 0.566, data is not normal
# J Nyumbu
# Statistic: 0.753
# 15.000: 0.526, data is not normal
# MJ Hoggard
# Statistic: 7.396
# 15.000: 0.568, data is not normal
# A Flintoff
# Statistic: 8.070
# 15.000: 0.567, data is not normal
# LE Plunkett
# Statistic: 2.902
# 15.000: 0.552, data is not normal
# SI Mahmood
# Statistic: 0.551
# 15.000: 0.510, data is not normal
# M Labuschagne
# Statistic: 1.819
# 15.000: 0.536, data is not normal
# PM Pushpakumara
# Statistic: 3.155
# 15.000: 0.556, data is not normal
# PADLR Sandakan
# Statistic: 1.769
# 15.000: 0.557, data is not normal
# MD Gunathilaka
# Statistic: 0.782
# 15.000: 0.507, data is not normal
# Mohammad Abbas
# Statistic: 10.634
# 15.000: 0.568, data is not normal
# Asad Shafiq
# Statistic: 0.895
# 15.000: 0.517, data is not normal
# Aizaz Cheema
# Statistic: 3.407
# 15.000: 0.554, data is not normal
# Abdur Rehman
# Statistic: 21.251
# 15.000: 0.571, data is not normal
# CJ Anderson
# Statistic: 1.398
# 15.000: 0.543, data is not normal
# N Deonarine
# Statistic: 5.915
# 15.000: 0.558, data is not normal
# PT Collins
# Statistic: 2.070
# 15.000: 0.536, data is not normal
# RR Sarwan
# Statistic: 0.580
# 15.000: 0.527, data is not normal
# SJ Harmison
# Statistic: 6.417
# 15.000: 0.567, data is not normal
# AF Giles
# Statistic: 2.193
# 15.000: 0.554, data is not normal
# IR Bell
# Statistic: 0.314
# 15.000: 0.519, data may be normal
# 10.000: 0.591, data may be normal
# 5.000: 0.709, data may be normal
# 2.500: 0.827, data may be normal
# 1.000: 0.984, data may be normal
# Kuldeep Yadav
# Statistic: 1.211
# 15.000: 0.539, data is not normal
# SR Harmer
# Statistic: 1.570
# 15.000: 0.553, data is not normal
# S van Zyl
# Statistic: 1.160
# 15.000: 0.510, data is not normal
# G Onions
# Statistic: 2.769
# 15.000: 0.558, data is not normal
# R Rampaul
# Statistic: 10.161
# 15.000: 0.566, data is not normal
# RP Singh
# Statistic: 2.749
# 15.000: 0.563, data is not normal
# S Sreesanth
# Statistic: 8.434
# 15.000: 0.569, data is not normal
# SK Raina
# Statistic: 1.715
# 15.000: 0.544, data is not normal
# A Mishra
# Statistic: 7.066
# 15.000: 0.567, data is not normal
# JM Bird
# Statistic: 4.400
# 15.000: 0.559, data is not normal
# T Panyangara
# Statistic: 3.409
# 15.000: 0.547, data is not normal
# E Chigumbura
# Statistic: 2.609
# 15.000: 0.544, data is not normal
# N M'shangwe
# Statistic: 2.289
# 15.000: 0.552, data is not normal
# Taskin Ahmed
# Statistic: 1.344
# 15.000: 0.548, data is not normal
# Kamrul Islam Rabbi
# Statistic: 0.768
# 15.000: 0.529, data is not normal
# Sabbir Rahman
# Statistic: 0.826
# 15.000: 0.497, data is not normal
# Tanvir Ahmed (1)
# Statistic: 2.207
# 15.000: 0.548, data is not normal
# L Sipamla
# Statistic: 0.903
# 15.000: 0.513, data is not normal
# PWA Mulder
# Statistic: 1.279
# 15.000: 0.517, data is not normal
# Mohammad Irfan
# Statistic: 0.962
# 15.000: 0.531, data is not normal
# Zulfiqar Babar
# Statistic: 4.300
# 15.000: 0.560, data is not normal
# KA Jamieson
# Statistic: 1.987
# 15.000: 0.539, data is not normal
# WB Rankin
# Statistic: 1.275
# 15.000: 0.523, data is not normal
# FDM Karunaratne
# Statistic: 0.705
# 15.000: 0.516, data is not normal
# UWMBCA Welegedara
# Statistic: 3.315
# 15.000: 0.563, data is not normal
# J Yadav
# Statistic: 1.024
# 15.000: 0.540, data is not normal
# Mustafizur Rahman
# Statistic: 3.566
# 15.000: 0.559, data is not normal
# Subashis Roy
# Statistic: 2.335
# 15.000: 0.548, data is not normal
# KD Mills
# Statistic: 3.645
# 15.000: 0.558, data is not normal
# JDP Oram
# Statistic: 6.978
# 15.000: 0.560, data is not normal
# Yuvraj Singh
# Statistic: 2.656
# 15.000: 0.536, data is not normal
# JC Tredwell
# Statistic: 1.155
# 15.000: 0.522, data is not normal
# Ehsan Adil
# Statistic: 1.795
# 15.000: 0.541, data is not normal
# Usman Shinwari
# Statistic: 0.531
# 15.000: 0.498, data is not normal
# Naseem Shah
# Statistic: 1.657
# 15.000: 0.554, data is not normal
# Mahbubul Alam
# Statistic: 1.205
# 15.000: 0.523, data is not normal
# Mehrab Hossain jnr
# Statistic: 0.957
# 15.000: 0.503, data is not normal
# TS Roland-Jones
# Statistic: 0.546
# 15.000: 0.498, data is not normal
# SD Udal
# Statistic: 1.572
# 15.000: 0.521, data is not normal
# Nasir Hossain
# Statistic: 3.664
# 15.000: 0.537, data is not normal
# Suhrawadi Shuvo
# Statistic: 0.758
# 15.000: 0.511, data is not normal
# Naeem Islam
# Statistic: 0.936
# 15.000: 0.520, data is not normal
# JEC Franklin
# Statistic: 2.942
# 15.000: 0.558, data is not normal
# NJ Astle
# Statistic: 1.527
# 15.000: 0.534, data is not normal
# MM Patel
# Statistic: 5.520
# 15.000: 0.561, data is not normal
# KMA Paul
# Statistic: 1.351
# 15.000: 0.528, data is not normal
# SH Lewis
# Statistic: 0.926
# 15.000: 0.531, data is not normal
# SW Masakadza
# Statistic: 2.424
# 15.000: 0.552, data is not normal
# Sohail Khan
# Statistic: 2.264
# 15.000: 0.557, data is not normal
# Imran Khan (2)
# Statistic: 1.253
# 15.000: 0.545, data is not normal
# Fawad Alam
# Statistic: 0.463
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.679, data may be normal
# 2.500: 0.792, data may be normal
# 1.000: 0.942, data may be normal
# R McLaren
# Statistic: 0.773
# 15.000: 0.521, data is not normal
# RJ Peterson
# Statistic: 2.675
# 15.000: 0.544, data is not normal
# J Lewis
# Statistic: 0.634
# 15.000: 0.508, data is not normal
# A Mithun
# Statistic: 1.210
# 15.000: 0.549, data is not normal
# BP Martin
# Statistic: 4.338
# 15.000: 0.552, data is not normal
# Yamin Ahmadzai
# Statistic: 1.674
# 15.000: 0.521, data is not normal
# Wafadar Momand
# Statistic: 1.435
# 15.000: 0.520, data is not normal
# Mohammad Nabi
# Statistic: 1.197
# 15.000: 0.517, data is not normal
# Rashid Khan
# Statistic: 2.735
# 15.000: 0.536, data is not normal
# Waqar Salamkheil
# Statistic: 0.751
# 15.000: 0.497, data is not normal
# WRS de Silva
# Statistic: 0.543
# 15.000: 0.497, data is not normal
# MF Maharoof
# Statistic: 5.337
# 15.000: 0.564, data is not normal
# Bilawal Bhatti
# Statistic: 0.521
# 15.000: 0.498, data is not normal
# DR Tuffey
# Statistic: 2.935
# 15.000: 0.544, data is not normal
# Mohammad Shahid
# Statistic: 3.126
# 15.000: 0.548, data is not normal
# Shuvagata Hom
# Statistic: 2.513
# 15.000: 0.546, data is not normal
# Jubair Hossain
# Statistic: 0.419
# 15.000: 0.537, data may be normal
# 10.000: 0.612, data may be normal
# 5.000: 0.734, data may be normal
# 2.500: 0.856, data may be normal
# 1.000: 1.018, data may be normal
# LH Ferguson
# Statistic: 0.303
# 15.000: 0.498, data may be normal
# 10.000: 0.567, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.944, data may be normal
# JA Raval
# Statistic: 0.709
# 15.000: 0.497, data is not normal
# DM Washington
# Statistic: 0.483
# 15.000: 0.510, data may be normal
# 10.000: 0.580, data may be normal
# 5.000: 0.696, data may be normal
# 2.500: 0.812, data may be normal
# 1.000: 0.966, data may be normal
# IJL Trott
# Statistic: 1.879
# 15.000: 0.539, data is not normal
# CK Langeveldt
# Statistic: 0.980
# 15.000: 0.498, data is not normal
# Syed Rasel
# Statistic: 0.541
# 15.000: 0.535, data is not normal
# Al-Amin Hossain
# Statistic: 3.266
# 15.000: 0.552, data is not normal
# DR Smith
# Statistic: 0.441
# 15.000: 0.503, data may be normal
# 10.000: 0.573, data may be normal
# 5.000: 0.687, data may be normal
# 2.500: 0.802, data may be normal
# 1.000: 0.954, data may be normal
# D Olivier
# Statistic: 2.120
# 15.000: 0.538, data is not normal
# KMDN Kulasekara
# Statistic: 4.294
# 15.000: 0.566, data is not normal
# CJ Jordan
# Statistic: 2.123
# 15.000: 0.545, data is not normal
# JJ Krejza
# Statistic: 0.816
# 15.000: 0.534, data is not normal
# TJ Murtagh
# Statistic: 1.821
# 15.000: 0.526, data is not normal
# SR Thompson
# Statistic: 1.678
# 15.000: 0.514, data is not normal
# GC Tonge
# Statistic: 0.875
# 15.000: 0.503, data is not normal
# RS Bopara
# Statistic: 0.236
# 15.000: 0.498, data may be normal
# 10.000: 0.567, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.944, data may be normal
# SCG MacGill
# Statistic: 3.426
# 15.000: 0.549, data is not normal
# MVT Fernando
# Statistic: 2.355
# 15.000: 0.558, data is not normal
# TK Curran
# Statistic: 0.570
# 15.000: 0.508, data is not normal
# Sohag Gazi
# Statistic: 6.872
# 15.000: 0.565, data is not normal
# HMCM Bandara
# Statistic: 2.074
# 15.000: 0.538, data is not normal
# L Embuldeniya
# Statistic: 2.150
# 15.000: 0.561, data is not normal
# NLTC Perera
# Statistic: 0.754
# 15.000: 0.530, data is not normal
# AJ Hall
# Statistic: 2.556
# 15.000: 0.501, data is not normal
# Ebadat Hossain
# Statistic: 1.706
# 15.000: 0.501, data is not normal
# Abu Jayed
# Statistic: 2.987
# 15.000: 0.544, data is not normal
# MD Shanaka
# Statistic: 1.162
# 15.000: 0.514, data is not normal
# Shahid Afridi
# Statistic: 1.114
# 15.000: 0.510, data is not normal
# Imran Farhat
# Statistic: 0.433
# 15.000: 0.501, data may be normal
# 10.000: 0.571, data may be normal
# 5.000: 0.685, data may be normal
# 2.500: 0.799, data may be normal
# 1.000: 0.951, data may be normal
# Iftikhar Anjum
# Statistic: 0.257
# 15.000: 0.498, data may be normal
# 10.000: 0.567, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.944, data may be normal
# DM Bess
# Statistic: 1.236
# 15.000: 0.506, data is not normal
# CR Brathwaite
# Statistic: 0.906
# 15.000: 0.541, data is not normal
# WER Somerville
# Statistic: 0.821
# 15.000: 0.527, data is not normal
# CT Mumba
# Statistic: 1.307
# 15.000: 0.536, data is not normal
# SE Bond
# Statistic: 1.278
# 15.000: 0.544, data is not normal
# LL Tsotsobe
# Statistic: 0.688
# 15.000: 0.506, data is not normal
# VRV Singh
# Statistic: 0.442
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.679, data may be normal
# 2.500: 0.792, data may be normal
# 1.000: 0.942, data may be normal
# GC Smith
# Statistic: 0.482
# 15.000: 0.523, data may be normal
# 10.000: 0.596, data may be normal
# 5.000: 0.715, data may be normal
# 2.500: 0.834, data may be normal
# 1.000: 0.992, data may be normal
# Iftikhar Ahmed
# Statistic: 0.469
# 15.000: 0.500, data may be normal
# 10.000: 0.569, data may be normal
# 5.000: 0.683, data may be normal
# 2.500: 0.797, data may be normal
# 1.000: 0.948, data may be normal
# TD Astle
# Statistic: 0.668
# 15.000: 0.529, data is not normal
# RK Kleinveldt
# Statistic: 1.112
# 15.000: 0.508, data is not normal
# PP Chawla
# Statistic: 0.614
# 15.000: 0.536, data is not normal
# JL Gunn
# Statistic: 1.935
# 15.000: 0.516, data is not normal
# D Hazell
# Statistic: 0.800
# 15.000: 0.501, data is not normal
# P Kumar
# Statistic: 3.590
# 15.000: 0.550, data is not normal
# Shadab Khan
# Statistic: 1.151
# 15.000: 0.530, data is not normal
# ST Jayasuriya
# Statistic: 0.237
# 15.000: 0.501, data may be normal
# 10.000: 0.571, data may be normal
# 5.000: 0.685, data may be normal
# 2.500: 0.799, data may be normal
# 1.000: 0.951, data may be normal
# Yasir Arafat
# Statistic: 1.544
# 15.000: 0.552, data is not normal
# P Utseya
# Statistic: 1.409
# 15.000: 0.511, data is not normal
# CH Morris
# Statistic: 1.509
# 15.000: 0.535, data is not normal
# C Green
# Statistic: 0.457
# 15.000: 0.507, data may be normal
# 10.000: 0.578, data may be normal
# 5.000: 0.693, data may be normal
# 2.500: 0.808, data may be normal
# 1.000: 0.961, data may be normal
# T Shamsi
# Statistic: 1.181
# 15.000: 0.514, data is not normal
# RA Reifer
# Statistic: 1.359
# 15.000: 0.501, data is not normal
# KK Peters
# Statistic: 1.145
# 15.000: 0.506, data is not normal
# Mohammad Sharif
# Statistic: 0.555
# 15.000: 0.514, data is not normal
# DE Bernard
# Statistic: 0.418
# 15.000: 0.498, data may be normal
# 10.000: 0.567, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.944, data may be normal
# RA Austin
# Statistic: 0.924
# 15.000: 0.497, data is not normal
# Muhammad Musa
# Statistic: 0.364
# 15.000: 0.506, data may be normal
# 10.000: 0.577, data may be normal
# 5.000: 0.692, data may be normal
# 2.500: 0.807, data may be normal
# 1.000: 0.960, data may be normal
# Nazmul Islam
# Statistic: 1.423
# 15.000: 0.511, data is not normal
# J Botha
# Statistic: 1.354
# 15.000: 0.522, data is not normal
# S Muthusamy
# Statistic: 1.248
# 15.000: 0.526, data is not normal
# J Goswami
# Statistic: 1.178
# 15.000: 0.498, data is not normal
# N Niranjana
# Statistic: 0.931
# 15.000: 0.497, data is not normal
# BJ Arnel
# Statistic: 1.341
# 15.000: 0.529, data is not normal
# BV Vitori
# Statistic: 0.601
# 15.000: 0.514, data is not normal
# JA Morkel
# Statistic: 0.445
# 15.000: 0.497, data may be normal
# 10.000: 0.566, data may be normal
# 5.000: 0.679, data may be normal
# 2.500: 0.792, data may be normal
# 1.000: 0.942, data may be normal
# Abul Hasan
# Statistic: 0.383
# 15.000: 0.517, data may be normal
# 10.000: 0.589, data may be normal
# 5.000: 0.707, data may be normal
# 2.500: 0.824, data may be normal
# 1.000: 0.980, data may be normal
# Elias Sunny
# Statistic: 0.365
# 15.000: 0.505, data may be normal
# 10.000: 0.575, data may be normal
# 5.000: 0.690, data may be normal
# 2.500: 0.804, data may be normal
# 1.000: 0.957, data may be normal
# B Muzarabani
# Statistic: 0.797
# 15.000: 0.497, data is not normal
# MS Dhoni
# Statistic: 0.233
# 15.000: 0.519, data may be normal
# 10.000: 0.591, data may be normal
# 5.000: 0.709, data may be normal
# 2.500: 0.827, data may be normal
# 1.000: 0.984, data may be normal
# C Munro
# Statistic: 0.696
# 15.000: 0.503, data is not normal
# SC Kerrigan
# Statistic: 0.539
# 15.000: 0.519, data is not normal
# JT Ball
# Statistic: 1.045
# 15.000: 0.505, data is not normal
# MR Gillespie
# Statistic: 1.174
# 15.000: 0.539, data is not normal
# M Zondeki
# Statistic: 1.444
# 15.000: 0.536, data is not normal
# MJ Leach
# Statistic: 0.603
# 15.000: 0.517, data is not normal
# HH Streak
# Statistic: 0.824
# 15.000: 0.511, data is not normal
# NB Mahwire
# Statistic: 0.523
# 15.000: 0.516, data is not normal
# SP Jones
# Statistic: 0.391
# 15.000: 0.516, data may be normal
# 10.000: 0.587, data may be normal
# 5.000: 0.705, data may be normal
# 2.500: 0.822, data may be normal
# 1.000: 0.978, data may be normal
# Mohammad Talha
# Statistic: 1.133
# 15.000: 0.536, data is not normal
# Mohammed Siraj
# Statistic: 2.581
# 15.000: 0.531, data is not normal
# GF Linde
# Statistic: 1.812
# 15.000: 0.522, data is not normal
# GB Hogg
# Statistic: 1.667
# 15.000: 0.522, data is not normal
# Faheem Ashraf
# Statistic: 1.385
# 15.000: 0.534, data is not normal
# JW Hastings
# Statistic: 1.467
# 15.000: 0.506, data is not normal
# NA Saini
# Statistic: 0.568
# 15.000: 0.497, data is not normal
# TE Kane
# Statistic: 0.616
# 15.000: 0.506, data is not normal
# NT Pascal
# Statistic: 0.428
# 15.000: 0.498, data may be normal
# 10.000: 0.567, data may be normal
# 5.000: 0.680, data may be normal
# 2.500: 0.793, data may be normal
# 1.000: 0.944, data may be normal
# KO Meth
# Statistic: 1.755
# 15.000: 0.510, data is not normal
# SW Tait
# Statistic: 0.543
# 15.000: 0.497, data is not normal
# CJ Sayers
# Statistic: 0.891
# 15.000: 0.527, data is not normal
# SS Cottrell
# Statistic: 0.368
# 15.000: 0.518, data may be normal
# 10.000: 0.590, data may be normal
# 5.000: 0.708, data may be normal
# 2.500: 0.826, data may be normal
# 1.000: 0.983, data may be normal
# Mujeeb Ur Rahman
# Statistic: 0.818
# 15.000: 0.498, data is not normal
# JA Richardson
# Statistic: 0.620
# 15.000: 0.497, data is not normal
# C Karunaratne
# Statistic: 0.428
# 15.000: 0.510, data may be normal
# 10.000: 0.580, data may be normal
# 5.000: 0.696, data may be normal
# 2.500: 0.812, data may be normal
# 1.000: 0.966, data may be normal
# KL Cross
# Statistic: 0.272
# 15.000: 0.500, data may be normal
# 10.000: 0.569, data may be normal
# 5.000: 0.683, data may be normal
# 2.500: 0.797, data may be normal
# 1.000: 0.948, data may be normal
# HC Knight
# Statistic: 1.234
# 15.000: 0.498, data is not normal
# 390 34
